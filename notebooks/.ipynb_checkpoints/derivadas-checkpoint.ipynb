# %%
from sympy import init_session
from sympy import div, QQ
from sympy.parsing.latex import parse_latex
from sympy.parsing.sympy_parser import parse_expr
from IPython.display import Markdown as md
from IPython.display import display
import pandas as pd

import numpy as np




init_session()

a, b, c, d = symbols('a b c d', real = True)
from docparts import añadir_ejercicios, doc_ejer, escribir_preambulo, escribir_ejercicios, escribir_fin

df_ejercicios = pd.DataFrame()

fichero = 'derivadas'
titulo = 'Derivadas'
curso = '2BCccss'


x,y = symbols('x, y', real=True)

import matplotlib.pyplot as plt
from matplotlib import style
#style.use('ggplot')
style.use('seaborn-whitegrid')


# %matplotlib inline
# Out:
# IPython console for SymPy 1.4 (Python 3.6.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.4/

# %%
puntuacion = '1'                          
                      
datos =  [  
            '2*x','3*x-5','2*x**2 -7*x+5','7*x** 5 -3*x**2 +x+2345',
            'x*(x+2)','(x+1)*(x-1)', '5/7*x**4 -1/55 *x**3 -3/4* x**2 + x - 1255',
            '(x+1)**3','(x**3 +x+1)** 4','(3*x+1)**2 - (3*x-1)**2',
            '1/x**2','1/(x+1)','(x**2 - 3)/(x**3 + x)','(x + 1)/x','(x*(x**2-1))/(3*x**2-3)',
            'x**(-3)','x**(1/2)','x**(2/3)','x**(-2/3)',
    
   
         ]
        
n_ejercicio = 'p25e16'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex(simplify(diff(S(t),'x')))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=2 x$ $ \rightarrow $$y'=2$
# $y=3 x - 5$ $ \rightarrow $$y'=3$
# $y=2 x^{2} - 7 x + 5$ $ \rightarrow $$y'=4 x - 7$
# $y=7 x^{5} - 3 x^{2} + x + 2345$ $ \rightarrow $$y'=35 x^{4} - 6 x + 1$
# $y=x \left(x + 2\right)$ $ \rightarrow $$y'=2 x + 2$
# $y=\left(x - 1\right) \left(x + 1\right)$ $ \rightarrow $$y'=2 x$
# $y=\frac{5 x^{4}}{7} - \frac{x^{3}}{55} - \frac{3 x^{2}}{4} + x - 1255$ $ \rightarrow $$y'=\frac{20 x^{3}}{7} - \frac{3 x^{2}}{55} - \frac{3 x}{2} + 1$
# $y=\left(x + 1\right)^{3}$ $ \rightarrow $$y'=3 \left(x + 1\right)^{2}$
# $y=\left(x^{3} + x + 1\right)^{4}$ $ \rightarrow $$y'=\left(12 x^{2} + 4\right) \left(x^{3} + x + 1\right)^{3}$
# $y=- \left(3 x - 1\right)^{2} + \left(3 x + 1\right)^{2}$ $ \rightarrow $$y'=12$
# $y=\frac{1}{x^{2}}$ $ \rightarrow $$y'=- \frac{2}{x^{3}}$
# $y=\frac{1}{x + 1}$ $ \rightarrow $$y'=- \frac{1}{\left(x + 1\right)^{2}}$
# $y=\frac{x^{2} - 3}{x^{3} + x}$ $ \rightarrow $$y'=\frac{- x^{4} + 10 x^{2} + 3}{x^{2} \left(x^{4} + 2 x^{2} + 1\right)}$
# $y=\frac{x + 1}{x}$ $ \rightarrow $$y'=- \frac{1}{x^{2}}$
# $y=\frac{x \left(x^{2} - 1\right)}{3 x^{2} - 3}$ $ \rightarrow $$y'=\frac{1}{3}$
# $y=\frac{1}{x^{3}}$ $ \rightarrow $$y'=- \frac{3}{x^{4}}$
# $y=x^{\frac{1}{2}}$ $ \rightarrow $$y'=\frac{1}{2 \sqrt{x}}$
# $y=x^{\frac{2}{3}}$ $ \rightarrow $$y'=\frac{2}{3 \sqrt[3]{x}}$
# $y=x^{\frac{-2}{3}}$ $ \rightarrow $$y'=- \frac{2}{3 x^{\frac{5}{3}}}$

# %%
puntuacion = '1'                          
                      
datos =  [  
            'x**(1/2)+x**(1/6)+x**(1/5)','sqrt(3*x)','x**3/sqrt(x)','x**3*x**(1/3)',
            'sqrt(x)/x','(1-x**2)**3','sqrt(2*x-4)','sqrt(2-x)',
            'cbrt((2*x**2))','sqrt(3*x**2-1)','(2*x)/(sqrt(x-1))','sqrt((1-x)/(1-x))',
            'E**(2*x)','2**(5*x)','8**(3*x**2-1)','a**x*x**a',
            'E**(sqrt(x))','log((2*x-1),10)','log(x+3)'
    
    
   
         ]
        
n_ejercicio = 'p25e16cont'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex(simplify(diff(S(t),'x')))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=x^{\frac{1}{2}} + x^{\frac{1}{5}} + x^{\frac{1}{6}}$ $ \rightarrow $$y'=\frac{\frac{x^{\frac{49}{30}}}{2} + \frac{x^{\frac{13}{10}}}{6} + \frac{x^{\frac{4}{3}}}{5}}{x^{\frac{32}{15}}}$
# $y=\sqrt{3} \sqrt{x}$ $ \rightarrow $$y'=\frac{\sqrt{3}}{2 \sqrt{x}}$
# $y=\frac{x^{3}}{\sqrt{x}}$ $ \rightarrow $$y'=\frac{5 x^{\frac{3}{2}}}{2}$
# $y=x^{3} x^{\frac{1}{3}}$ $ \rightarrow $$y'=\frac{10 x^{\frac{7}{3}}}{3}$
# $y=\frac{\sqrt{x}}{x}$ $ \rightarrow $$y'=- \frac{1}{2 x^{\frac{3}{2}}}$
# $y=\left(1 - x^{2}\right)^{3}$ $ \rightarrow $$y'=- 6 x \left(x^{2} - 1\right)^{2}$
# $y=\sqrt{2 x - 4}$ $ \rightarrow $$y'=\frac{\sqrt{2}}{2 \sqrt{x - 2}}$
# $y=\sqrt{2 - x}$ $ \rightarrow $$y'=- \frac{1}{2 \sqrt{2 - x}}$
# $y=\sqrt[3]{2} \sqrt[3]{x^{2}}$ $ \rightarrow $$y'=\frac{2 \sqrt[3]{2} \sqrt[3]{x^{2}}}{3 x}$
# $y=\sqrt{3 x^{2} - 1}$ $ \rightarrow $$y'=\frac{3 x}{\sqrt{3 x^{2} - 1}}$
# $y=\frac{2 x}{\sqrt{x - 1}}$ $ \rightarrow $$y'=\frac{x - 2}{\left(x - 1\right)^{\frac{3}{2}}}$
# $y=\sqrt{1}$ $ \rightarrow $$y'=0$
# $y=e^{2 x}$ $ \rightarrow $$y'=2 e^{2 x}$
# $y=2^{5 x}$ $ \rightarrow $$y'=32^{x} \log{\left(32 \right)}$
# $y=8^{3 x^{2} - 1}$ $ \rightarrow $$y'=9 \cdot 2^{9 x^{2} - 2} x \log{\left(2 \right)}$
# $y=a^{x} x^{a}$ $ \rightarrow $$y'=a^{x} x^{a - 1} \left(a + x \log{\left(a \right)}\right)$
# $y=e^{\sqrt{x}}$ $ \rightarrow $$y'=\frac{e^{\sqrt{x}}}{2 \sqrt{x}}$
# $y=\frac{\log{\left(2 x - 1 \right)}}{\log{\left(10 \right)}}$ $ \rightarrow $$y'=\frac{2}{\left(2 x - 1\right) \log{\left(10 \right)}}$
# $y=\log{\left(x + 3 \right)}$ $ \rightarrow $$y'=\frac{1}{x + 3}$

# %%
puntuacion = '1'                          
                      
datos =  [  
            'log(3*x**2-7)','log((x-2)**2)','log((x**2-2*x),10)',
            'log((2*x**3+3*x**2),2)','sqrt(log(x))','log(x)/x', 'log((1-x)/(1+x))',
            'log(root(x**3,4))', 'log((1+2*x),4)','log((E**x)/(E**x-1))',
            '(1-log(x))/(1+log(x))','E**x/(x-1)',
            '(E**x-E**(-x))/(E**x+E**(-x))','E**(sqrt(x**2+1))', 'sin(2*x)',
            'sin(7*x-3)','cos(5*x)','3*tan(2*x)','(sin(x))**2', '(sin(x**2))'
    
    
   
         ]
        
n_ejercicio = 'p25e17'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex(simplify(diff(S(t),'x')))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=\log{\left(3 x^{2} - 7 \right)}$ $ \rightarrow $$y'=\frac{6 x}{3 x^{2} - 7}$
# $y=\log{\left(\left(x - 2\right)^{2} \right)}$ $ \rightarrow $$y'=\frac{2}{x - 2}$
# $y=\frac{\log{\left(x^{2} - 2 x \right)}}{\log{\left(10 \right)}}$ $ \rightarrow $$y'=\frac{2 \left(x - 1\right)}{x \left(x - 2\right) \log{\left(10 \right)}}$
# $y=\frac{\log{\left(2 x^{3} + 3 x^{2} \right)}}{\log{\left(2 \right)}}$ $ \rightarrow $$y'=\frac{6 \left(x + 1\right)}{x \left(2 x + 3\right) \log{\left(2 \right)}}$
# $y=\sqrt{\log{\left(x \right)}}$ $ \rightarrow $$y'=\frac{1}{2 x \sqrt{\log{\left(x \right)}}}$
# $y=\frac{\log{\left(x \right)}}{x}$ $ \rightarrow $$y'=\frac{1 - \log{\left(x \right)}}{x^{2}}$
# $y=\log{\left(\frac{1 - x}{x + 1} \right)}$ $ \rightarrow $$y'=\frac{2}{x^{2} - 1}$
# $y=\log{\left(\sqrt[4]{x^{3}} \right)}$ $ \rightarrow $$y'=\frac{3}{4 x}$
# $y=\frac{\log{\left(2 x + 1 \right)}}{\log{\left(4 \right)}}$ $ \rightarrow $$y'=\frac{1}{\left(2 x + 1\right) \log{\left(2 \right)}}$
# $y=\log{\left(\frac{e^{x}}{e^{x} - 1} \right)}$ $ \rightarrow $$y'=\frac{1}{1 - e^{x}}$
# $y=\frac{1 - \log{\left(x \right)}}{\log{\left(x \right)} + 1}$ $ \rightarrow $$y'=- \frac{2}{x \left(\log{\left(x \right)} + 1\right)^{2}}$
# $y=\frac{e^{x}}{x - 1}$ $ \rightarrow $$y'=\frac{\left(x - 2\right) e^{x}}{x^{2} - 2 x + 1}$
# $y=\frac{e^{x} - e^{- x}}{e^{x} + e^{- x}}$ $ \rightarrow $$y'=\frac{4 e^{2 x}}{e^{4 x} + 2 e^{2 x} + 1}$
# $y=e^{\sqrt{x^{2} + 1}}$ $ \rightarrow $$y'=\frac{x e^{\sqrt{x^{2} + 1}}}{\sqrt{x^{2} + 1}}$
# $y=\sin{\left(2 x \right)}$ $ \rightarrow $$y'=2 \cos{\left(2 x \right)}$
# $y=\sin{\left(7 x - 3 \right)}$ $ \rightarrow $$y'=7 \cos{\left(7 x - 3 \right)}$
# $y=\cos{\left(5 x \right)}$ $ \rightarrow $$y'=- 5 \sin{\left(5 x \right)}$
# $y=3 \tan{\left(2 x \right)}$ $ \rightarrow $$y'=\frac{6}{\cos^{2}{\left(2 x \right)}}$
# $y=\sin^{2}{\left(x \right)}$ $ \rightarrow $$y'=\sin{\left(2 x \right)}$
# $y=\sin{\left(x^{2} \right)}$ $ \rightarrow $$y'=2 x \cos{\left(x^{2} \right)}$

# %%
puntuacion = '1'                          
                      
datos =  [  
            '(cos(x**2+1))**2','(tan(5*x))**3','(sin(4*x))**3','sqrt(sin(2*x))',
            'log(tan(1-x))','cbrt(sin(x))','(sin(x))**3*cos(x)',
            'sec(5*x+2)','asin(2*x)','acos(x**2)','atan((x-1)/(1-x))', 'asin((x+1)/(x-1))',
            '(tan(sin(x)))**2','root(sin(x),x)','x**tan(x)','2**log(cos(x))',
            '(sin(x))**atan(x)','(atan(x))**x','x**sec(x)'
    
    
   
         ]
        
n_ejercicio = 'p25e17cont'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex(simplify(diff(S(t),'x')))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '1', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=\cos^{2}{\left(x^{2} + 1 \right)}$ $ \rightarrow $$y'=- 2 x \sin{\left(2 x^{2} + 2 \right)}$
# $y=\tan^{3}{\left(5 x \right)}$ $ \rightarrow $$y'=\frac{15 \tan^{2}{\left(5 x \right)}}{\cos^{2}{\left(5 x \right)}}$
# $y=\sin^{3}{\left(4 x \right)}$ $ \rightarrow $$y'=12 \sin^{2}{\left(4 x \right)} \cos{\left(4 x \right)}$
# $y=\sqrt{\sin{\left(2 x \right)}}$ $ \rightarrow $$y'=\frac{\cos{\left(2 x \right)}}{\sqrt{\sin{\left(2 x \right)}}}$
# $y=\log{\left(- \tan{\left(x - 1 \right)} \right)}$ $ \rightarrow $$y'=\tan{\left(x - 1 \right)} + \frac{1}{\tan{\left(x - 1 \right)}}$
# $y=\sqrt[3]{\sin{\left(x \right)}}$ $ \rightarrow $$y'=\frac{\cos{\left(x \right)}}{3 \sin^{\frac{2}{3}}{\left(x \right)}}$
# $y=\sin^{3}{\left(x \right)} \cos{\left(x \right)}$ $ \rightarrow $$y'=\left(3 - 4 \sin^{2}{\left(x \right)}\right) \sin^{2}{\left(x \right)}$
# $y=\sec{\left(5 x + 2 \right)}$ $ \rightarrow $$y'=5 \tan{\left(5 x + 2 \right)} \sec{\left(5 x + 2 \right)}$
# $y=\operatorname{asin}{\left(2 x \right)}$ $ \rightarrow $$y'=\frac{2}{\sqrt{1 - 4 x^{2}}}$
# $y=\operatorname{acos}{\left(x^{2} \right)}$ $ \rightarrow $$y'=- \frac{2 x}{\sqrt{1 - x^{4}}}$
# $y=\operatorname{atan}{\left(\frac{x - 1}{1 - x} \right)}$ $ \rightarrow $$y'=0$
# $y=\operatorname{asin}{\left(\frac{x + 1}{x - 1} \right)}$ $ \rightarrow $$y'=- \frac{1}{\sqrt{- \frac{x}{x^{2} - 2 x + 1}} \left(x^{2} - 2 x + 1\right)}$
# $y=\tan^{2}{\left(\sin{\left(x \right)} \right)}$ $ \rightarrow $$y'=\frac{2 \cos{\left(x \right)} \tan{\left(\sin{\left(x \right)} \right)}}{\cos^{2}{\left(\sin{\left(x \right)} \right)}}$
# $y=\sin^{\frac{1}{x}}{\left(x \right)}$ $ \rightarrow $$y'=\frac{\left(x \cos{\left(x \right)} - \log{\left(\sin{\left(x \right)} \right)} \sin{\left(x \right)}\right) \sin^{-1 + \frac{1}{x}}{\left(x \right)}}{x^{2}}$
# $y=x^{\tan{\left(x \right)}}$ $ \rightarrow $$y'=x^{\tan{\left(x \right)} - 1} \left(\frac{x \log{\left(x \right)}}{\cos^{2}{\left(x \right)}} + \tan{\left(x \right)}\right)$
# $y=2^{\log{\left(\cos{\left(x \right)} \right)}}$ $ \rightarrow $$y'=- 2^{\log{\left(\cos{\left(x \right)} \right)}} \log{\left(2 \right)} \tan{\left(x \right)}$
# $y=\sin^{\operatorname{atan}{\left(x \right)}}{\left(x \right)}$ $ \rightarrow $$y'=\frac{\left(\left(x^{2} + 1\right) \cos{\left(x \right)} \operatorname{atan}{\left(x \right)} + \log{\left(\sin{\left(x \right)} \right)} \sin{\left(x \right)}\right) \sin^{\operatorname{atan}{\left(x \right)} - 1}{\left(x \right)}}{x^{2} + 1}$
# $y=\operatorname{atan}^{x}{\left(x \right)}$ $ \rightarrow $$y'=\frac{\left(x + \left(x^{2} + 1\right) \log{\left(\operatorname{atan}{\left(x \right)} \right)} \operatorname{atan}{\left(x \right)}\right) \operatorname{atan}^{x - 1}{\left(x \right)}}{x^{2} + 1}$
# $y=x^{\sec{\left(x \right)}}$ $ \rightarrow $$y'=x^{\sec{\left(x \right)} - 1} \left(x \log{\left(x \right)} \tan{\left(x \right)} + 1\right) \sec{\left(x \right)}$

# %%
puntuacion = '1'                          
                      
datos =  [  
            '(x**2-3)**4','(1-5*x)**6','cbrt(3*x**2)','(x**2+4)*(3*x**3+1)',
            'sqrt(2*x)+2*sqrt(x)','log((x**4)/((3*x+4)**3))','log(sqrt((x-1)/(x+1)))','log((x+3)**2)',
            'x**2*log(x)-x','log((x**2+1)*(2*x**2+3*x+1))','log(x+sqrt(1+x**2))',
            'x**2*sin(x)','asin(x**2+x)','x**2*acos(2/x)','log((E**x-1)/(2*E**x))',
            'log(x**2)/(x)','2**(x**2+3*x+1)','x*2**(x**2)','2**sin(x)', 'E**tan(x)'
    
    
   
         ]
        
n_ejercicio = 'p26e18'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex(simplify(diff(S(t),'x')))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=\left(x^{2} - 3\right)^{4}$ $ \rightarrow $$y'=8 x \left(x^{2} - 3\right)^{3}$
# $y=\left(1 - 5 x\right)^{6}$ $ \rightarrow $$y'=30 \left(5 x - 1\right)^{5}$
# $y=\sqrt[3]{3} \sqrt[3]{x^{2}}$ $ \rightarrow $$y'=\frac{2 \sqrt[3]{3} \sqrt[3]{x^{2}}}{3 x}$
# $y=\left(x^{2} + 4\right) \left(3 x^{3} + 1\right)$ $ \rightarrow $$y'=x \left(15 x^{3} + 36 x + 2\right)$
# $y=\sqrt{2} \sqrt{x} + 2 \sqrt{x}$ $ \rightarrow $$y'=\frac{\sqrt{2} + 2}{2 \sqrt{x}}$
# $y=\log{\left(\frac{x^{4}}{\left(3 x + 4\right)^{3}} \right)}$ $ \rightarrow $$y'=\frac{3 x + 16}{x \left(3 x + 4\right)}$
# $y=\log{\left(\sqrt{\frac{x - 1}{x + 1}} \right)}$ $ \rightarrow $$y'=\frac{1}{x^{2} - 1}$
# $y=\log{\left(\left(x + 3\right)^{2} \right)}$ $ \rightarrow $$y'=\frac{2}{x + 3}$
# $y=x^{2} \log{\left(x \right)} - x$ $ \rightarrow $$y'=2 x \log{\left(x \right)} + x - 1$
# $y=\log{\left(\left(x^{2} + 1\right) \left(2 x^{2} + 3 x + 1\right) \right)}$ $ \rightarrow $$y'=\frac{8 x^{3} + 9 x^{2} + 6 x + 3}{2 x^{4} + 3 x^{3} + 3 x^{2} + 3 x + 1}$
# $y=\log{\left(x + \sqrt{x^{2} + 1} \right)}$ $ \rightarrow $$y'=\frac{1}{\sqrt{x^{2} + 1}}$
# $y=x^{2} \sin{\left(x \right)}$ $ \rightarrow $$y'=x \left(x \cos{\left(x \right)} + 2 \sin{\left(x \right)}\right)$
# $y=\operatorname{asin}{\left(x^{2} + x \right)}$ $ \rightarrow $$y'=\frac{2 x + 1}{\sqrt{- x^{2} \left(x + 1\right)^{2} + 1}}$
# $y=x^{2} \operatorname{acos}{\left(\frac{2}{x} \right)}$ $ \rightarrow $$y'=2 x \operatorname{acos}{\left(\frac{2}{x} \right)} + \frac{2}{\sqrt{1 - \frac{4}{x^{2}}}}$
# $y=\log{\left(\frac{e^{x} - 1}{2 e^{x}} \right)}$ $ \rightarrow $$y'=\frac{1}{e^{x} - 1}$
# $y=\frac{\log{\left(x^{2} \right)}}{x}$ $ \rightarrow $$y'=\frac{2 - \log{\left(x^{2} \right)}}{x^{2}}$
# $y=2^{x^{2} + 3 x + 1}$ $ \rightarrow $$y'=2^{x \left(x + 3\right)} \left(2 x + 3\right) \log{\left(4 \right)}$
# $y=2^{x^{2}} x$ $ \rightarrow $$y'=2^{x^{2}} \left(x^{2} \log{\left(4 \right)} + 1\right)$
# $y=2^{\sin{\left(x \right)}}$ $ \rightarrow $$y'=2^{\sin{\left(x \right)}} \log{\left(2 \right)} \cos{\left(x \right)}$
# $y=e^{\tan{\left(x \right)}}$ $ \rightarrow $$y'=\frac{e^{\tan{\left(x \right)}}}{\cos^{2}{\left(x \right)}}$

# %%
puntuacion = '1'                          
                      
datos =  [  
            'x**log(x)','root(x,x)','(cos(x))**sin(x)','(sin(x**3))**3',
            'asin(cos(x))','asin(log(x))','3*(sin((2*x+1)**3))**2',
            'log((cos(x**2))**2)','log(sqrt((1+sin(2*x))/(1-sin(2*x))))','log((1-cos(x))/(1+cos(x)))',
            '1/2*log(tan(x/2))',
            '(sin(x)+cos(x))/(sin(x)-cos(x))','x*sqrt(a**2-x**2)+a**2*asin(x/a)',
            'cos(x)/(2*sin(x)**2)-1/2*log(tan(x/2))','E**x*(x-1)*(cos(log(x))+1/2*sin(log(x)))',

    
    
    
   
         ]
        
n_ejercicio = 'p26e18cont'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex(simplify(diff(S(t),'x')))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '1', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=x^{\log{\left(x \right)}}$ $ \rightarrow $$y'=2 x^{\log{\left(x \right)} - 1} \log{\left(x \right)}$
# $y=x^{\frac{1}{x}}$ $ \rightarrow $$y'=x^{-2 + \frac{1}{x}} \left(1 - \log{\left(x \right)}\right)$
# $y=\cos^{\sin{\left(x \right)}}{\left(x \right)}$ $ \rightarrow $$y'=\left(\log{\left(\cos{\left(x \right)} \right)} \cos^{2}{\left(x \right)} - \sin^{2}{\left(x \right)}\right) \cos^{\sin{\left(x \right)} - 1}{\left(x \right)}$
# $y=\sin^{3}{\left(x^{3} \right)}$ $ \rightarrow $$y'=9 x^{2} \sin^{2}{\left(x^{3} \right)} \cos{\left(x^{3} \right)}$
# $y=\operatorname{asin}{\left(\cos{\left(x \right)} \right)}$ $ \rightarrow $$y'=- \frac{\sin{\left(x \right)}}{\sqrt{\sin^{2}{\left(x \right)}}}$
# $y=\operatorname{asin}{\left(\log{\left(x \right)} \right)}$ $ \rightarrow $$y'=\frac{1}{x \sqrt{1 - \log{\left(x \right)}^{2}}}$
# $y=3 \sin^{2}{\left(\left(2 x + 1\right)^{3} \right)}$ $ \rightarrow $$y'=36 \left(2 x + 1\right)^{2} \sin{\left(\left(2 x + 1\right)^{3} \right)} \cos{\left(\left(2 x + 1\right)^{3} \right)}$
# $y=\log{\left(\cos^{2}{\left(x^{2} \right)} \right)}$ $ \rightarrow $$y'=- 4 x \tan{\left(x^{2} \right)}$
# $y=\log{\left(\sqrt{\frac{\sin{\left(2 x \right)} + 1}{1 - \sin{\left(2 x \right)}}} \right)}$ $ \rightarrow $$y'=\frac{2}{\cos{\left(2 x \right)}}$
# $y=\log{\left(\frac{1 - \cos{\left(x \right)}}{\cos{\left(x \right)} + 1} \right)}$ $ \rightarrow $$y'=\frac{2}{\sin{\left(x \right)}}$
# $y=\frac{\log{\left(\tan{\left(\frac{x}{2} \right)} \right)}}{2}$ $ \rightarrow $$y'=\frac{1}{2 \sin{\left(x \right)}}$
# $y=\frac{\sin{\left(x \right)} + \cos{\left(x \right)}}{\sin{\left(x \right)} - \cos{\left(x \right)}}$ $ \rightarrow $$y'=\frac{2}{\sin{\left(2 x \right)} - 1}$
# $y=a^{2} \operatorname{asin}{\left(\frac{x}{a} \right)} + x \sqrt{a^{2} - x^{2}}$ $ \rightarrow $$y'=\frac{a^{2}}{\sqrt{a^{2} - x^{2}}} + \frac{a}{\sqrt{1 - \frac{x^{2}}{a^{2}}}} - \frac{2 x^{2}}{\sqrt{a^{2} - x^{2}}}$
# $y=- \frac{\log{\left(\tan{\left(\frac{x}{2} \right)} \right)}}{2} + \frac{\cos{\left(x \right)}}{2 \sin^{2}{\left(x \right)}}$ $ \rightarrow $$y'=- \frac{1}{\left(\cos{\left(x \right)} + 1\right) \sin^{2}{\left(x \right)} \tan{\left(\frac{x}{2} \right)}}$
# $y=e^{x} \left(x - 1\right) \left(\frac{\sin{\left(\log{\left(x \right)} \right)}}{2} + \cos{\left(\log{\left(x \right)} \right)}\right)$ $ \rightarrow $$y'=\frac{\left(x^{2} \left(\sin{\left(\log{\left(x \right)} \right)} + 2 \cos{\left(\log{\left(x \right)} \right)}\right) + \left(1 - x\right) \left(2 \sin{\left(\log{\left(x \right)} \right)} - \cos{\left(\log{\left(x \right)} \right)}\right)\right) e^{x}}{2 x}$

# %%
puntuacion = '1'                          
                      
datos =  [  
            '(x**2-3)/(x**2+3)','((1-x)/(1+x))**(2/3)','log(x)/x','(E**x+E**(-x))/(E**x-E**(-x))','1/sin(x)',
            'atan(x/3)','(sin(x))**2', '(2*sqrt(x)-3)**7','(cos(7*x**2))**5',
            'cbrt((5*x-3)**2)','log(sqrt(1-x))','log(sqrt(tan(x)),2)','cbrt(sin(x**2))',
            'sqrt(x+sqrt(x))','sqrt(x*sqrt(x+1))','log((x*tan(x))**2)','log(1/x**2*cbrt(x**2-1))',
            'log(root((1)/(1+x)**2,4))','x**(x+1)', '(sin(x)/x)**x','E**(2*asin(x**2))',    
    
   
         ]
        
n_ejercicio = 'p27e27'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex(simplify(diff(S(t),'x')))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=\frac{x^{2} - 3}{x^{2} + 3}$ $ \rightarrow $$y'=\frac{12 x}{\left(x^{2} + 3\right)^{2}}$
# $y=\left(\frac{1 - x}{x + 1}\right)^{\frac{2}{3}}$ $ \rightarrow $$y'=\frac{4 \left(\frac{1 - x}{x + 1}\right)^{\frac{2}{3}}}{3 \left(x^{2} - 1\right)}$
# $y=\frac{\log{\left(x \right)}}{x}$ $ \rightarrow $$y'=\frac{1 - \log{\left(x \right)}}{x^{2}}$
# $y=\frac{e^{x} + e^{- x}}{e^{x} - e^{- x}}$ $ \rightarrow $$y'=- \frac{4 e^{2 x}}{e^{4 x} - 2 e^{2 x} + 1}$
# $y=\frac{1}{\sin{\left(x \right)}}$ $ \rightarrow $$y'=- \frac{\cos{\left(x \right)}}{\sin^{2}{\left(x \right)}}$
# $y=\operatorname{atan}{\left(\frac{x}{3} \right)}$ $ \rightarrow $$y'=\frac{3}{x^{2} + 9}$
# $y=\sin^{2}{\left(x \right)}$ $ \rightarrow $$y'=\sin{\left(2 x \right)}$
# $y=\left(2 \sqrt{x} - 3\right)^{7}$ $ \rightarrow $$y'=\frac{7 \left(2 \sqrt{x} - 3\right)^{6}}{\sqrt{x}}$
# $y=\cos^{5}{\left(7 x^{2} \right)}$ $ \rightarrow $$y'=- 70 x \sin{\left(7 x^{2} \right)} \cos^{4}{\left(7 x^{2} \right)}$
# $y=\sqrt[3]{\left(5 x - 3\right)^{2}}$ $ \rightarrow $$y'=\frac{10 \sqrt[3]{\left(5 x - 3\right)^{2}}}{3 \left(5 x - 3\right)}$
# $y=\log{\left(\sqrt{1 - x} \right)}$ $ \rightarrow $$y'=\frac{1}{2 \left(x - 1\right)}$
# $y=\frac{\log{\left(\sqrt{\tan{\left(x \right)}} \right)}}{\log{\left(2 \right)}}$ $ \rightarrow $$y'=\frac{1}{\log{\left(2 \right)} \sin{\left(2 x \right)}}$
# $y=\sqrt[3]{\sin{\left(x^{2} \right)}}$ $ \rightarrow $$y'=\frac{2 x \cos{\left(x^{2} \right)}}{3 \sin^{\frac{2}{3}}{\left(x^{2} \right)}}$
# $y=\sqrt{\sqrt{x} + x}$ $ \rightarrow $$y'=\frac{2 \sqrt{x} + 1}{4 \sqrt{x} \sqrt{\sqrt{x} + x}}$
# $y=\sqrt{x \sqrt{x + 1}}$ $ \rightarrow $$y'=\frac{\sqrt{x \sqrt{x + 1}} \left(3 x + 2\right)}{4 x \left(x + 1\right)}$
# $y=\log{\left(\left(x \tan{\left(x \right)}\right)^{2} \right)}$ $ \rightarrow $$y'=\frac{4}{\sin{\left(2 x \right)}} + \frac{2}{x}$
# $y=\log{\left(\frac{\sqrt[3]{x^{2} - 1}}{x^{2}} \right)}$ $ \rightarrow $$y'=\frac{2 \left(3 - 2 x^{2}\right)}{3 x \left(x^{2} - 1\right)}$
# $y=\log{\left(\sqrt[4]{\frac{1}{\left(x + 1\right)^{2}}} \right)}$ $ \rightarrow $$y'=- \frac{1}{2 x + 2}$
# $y=x^{x + 1}$ $ \rightarrow $$y'=x^{x} \left(x \log{\left(x \right)} + x + 1\right)$
# $y=\left(\frac{\sin{\left(x \right)}}{x}\right)^{x}$ $ \rightarrow $$y'=\left(\frac{\sin{\left(x \right)}}{x}\right)^{x} \left(\frac{x}{\tan{\left(x \right)}} + \log{\left(\frac{\sin{\left(x \right)}}{x} \right)} - 1\right)$
# $y=e^{2 \operatorname{asin}{\left(x^{2} \right)}}$ $ \rightarrow $$y'=\frac{4 x e^{2 \operatorname{asin}{\left(x^{2} \right)}}}{\sqrt{1 - x^{4}}}$

# %%
puntuacion = '1'                          
                      
datos =  [  
            'x**3*E**(4*x)*cos(x)', 'asin((2*x-1)/sqrt(5))','sin(x**2+cos(x))','(x*sin(x))/(E**x+1)',
            'atan((4*x-4*x**3)/(1-6*x**2+x**4))','log((tan(x-2)-2)/(2*tan(x-2)-1))','sqrt(log(tan(x**2+1)))',
            'asin(2*x*sqrt(1-x**2))','(1-cos(x))*cot(x)','atan((sqrt(1+x**2)-1)/x)',
            'E**log((sin(x)**2))','atan((1+x)/(1-x))-atan(x)','atan(x/(sqrt(1-x**2)))',
            '(cos(x))**log(x**2)', '(4*x+1)/(cos(2*x**2+x+1))**2', '(cos(x))*sin(x)',
            'cbrt((sin(3*x))/(1-sin(x)))','asin(sqrt((1-E**x)/(1+E**x)))','((1+x)*atan(x))/(log(x))',
            'atan(sqrt((1-cos(x))/(1+cos(x))))','(x**3/2-1/4)*asin(x)+x/4*sqrt(1-x**2)'
       
         ]
        
n_ejercicio = 'p27e27cont'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex(simplify(diff(S(t),'x')))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '1', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=e^{4 x} x^{3} \cos{\left(x \right)}$ $ \rightarrow $$y'=x^{2} \left(- x \sin{\left(x \right)} + 4 x \cos{\left(x \right)} + 3 \cos{\left(x \right)}\right) e^{4 x}$
# $y=\operatorname{asin}{\left(\frac{2 x - 1}{\sqrt{5}} \right)}$ $ \rightarrow $$y'=\frac{1}{\sqrt{- x^{2} + x + 1}}$
# $y=\sin{\left(x^{2} + \cos{\left(x \right)} \right)}$ $ \rightarrow $$y'=\left(2 x - \sin{\left(x \right)}\right) \cos{\left(x^{2} + \cos{\left(x \right)} \right)}$
# $y=\frac{x \sin{\left(x \right)}}{e^{x} + 1}$ $ \rightarrow $$y'=\frac{- x e^{x} \sin{\left(x \right)} + \left(x \cos{\left(x \right)} + \sin{\left(x \right)}\right) \left(e^{x} + 1\right)}{\left(e^{x} + 1\right)^{2}}$
# $y=\operatorname{atan}{\left(\frac{- 4 x^{3} + 4 x}{x^{4} - 6 x^{2} + 1} \right)}$ $ \rightarrow $$y'=\frac{4}{x^{2} + 1}$
# $y=\log{\left(\frac{\tan{\left(x - 2 \right)} - 2}{2 \tan{\left(x - 2 \right)} - 1} \right)}$ $ \rightarrow $$y'=\frac{3 \left(\tan^{2}{\left(x - 2 \right)} + 1\right)}{\left(\tan{\left(x - 2 \right)} - 2\right) \left(2 \tan{\left(x - 2 \right)} - 1\right)}$
# $y=\sqrt{\log{\left(\tan{\left(x^{2} + 1 \right)} \right)}}$ $ \rightarrow $$y'=\frac{x \left(\tan^{2}{\left(x^{2} + 1 \right)} + 1\right)}{\sqrt{\log{\left(\tan{\left(x^{2} + 1 \right)} \right)}} \tan{\left(x^{2} + 1 \right)}}$
# $y=\operatorname{asin}{\left(2 x \sqrt{1 - x^{2}} \right)}$ $ \rightarrow $$y'=\frac{2 \left(1 - 2 x^{2}\right)}{\sqrt{1 - x^{2}} \sqrt{- 4 x^{2} \left(1 - x^{2}\right) + 1}}$
# $y=\left(1 - \cos{\left(x \right)}\right) \cot{\left(x \right)}$ $ \rightarrow $$y'=\frac{\cos{\left(x \right)} - 1}{\sin^{2}{\left(x \right)}} + \cos{\left(x \right)}$
# $y=\operatorname{atan}{\left(\frac{\sqrt{x^{2} + 1} - 1}{x} \right)}$ $ \rightarrow $$y'=\frac{1}{2 \left(x^{2} + 1\right)}$
# $y=e^{\log{\left(\sin^{2}{\left(x \right)} \right)}}$ $ \rightarrow $$y'=\sin{\left(2 x \right)}$
# $y=- \operatorname{atan}{\left(x \right)} + \operatorname{atan}{\left(\frac{x + 1}{1 - x} \right)}$ $ \rightarrow $$y'=0$
# $y=\operatorname{atan}{\left(\frac{x}{\sqrt{1 - x^{2}}} \right)}$ $ \rightarrow $$y'=\frac{1}{\sqrt{1 - x^{2}}}$
# $y=\cos^{\log{\left(x^{2} \right)}}{\left(x \right)}$ $ \rightarrow $$y'=\frac{\left(- x \log{\left(x^{2} \right)} \sin{\left(x \right)} + 2 \log{\left(\cos{\left(x \right)} \right)} \cos{\left(x \right)}\right) \cos^{\log{\left(x^{2} \right)} - 1}{\left(x \right)}}{x}$
# $y=\frac{4 x + 1}{\cos^{2}{\left(2 x^{2} + x + 1 \right)}}$ $ \rightarrow $$y'=\frac{2 \left(\left(4 x + 1\right)^{2} \sin{\left(2 x^{2} + x + 1 \right)} + 2 \cos{\left(2 x^{2} + x + 1 \right)}\right)}{\cos^{3}{\left(2 x^{2} + x + 1 \right)}}$
# $y=\sin{\left(x \right)} \cos{\left(x \right)}$ $ \rightarrow $$y'=\cos{\left(2 x \right)}$
# $y=\sqrt[3]{\frac{\sin{\left(3 x \right)}}{1 - \sin{\left(x \right)}}}$ $ \rightarrow $$y'=- \frac{\sqrt[3]{- \frac{\sin{\left(3 x \right)}}{\sin{\left(x \right)} - 1}} \left(\frac{8 \sin^{3}{\left(x \right)} \cos{\left(x \right)}}{3} + \cos{\left(3 x \right)}\right)}{\left(\sin{\left(x \right)} - 1\right) \sin{\left(3 x \right)}}$
# $y=\operatorname{asin}{\left(\sqrt{\frac{1 - e^{x}}{e^{x} + 1}} \right)}$ $ \rightarrow $$y'=\frac{\sqrt{2} \sqrt{- \tanh{\left(\frac{x}{2} \right)}}}{4 \sqrt{\frac{e^{x}}{e^{x} + 1}} \sinh{\left(x \right)}}$
# $y=\frac{\left(x + 1\right) \operatorname{atan}{\left(x \right)}}{\log{\left(x \right)}}$ $ \rightarrow $$y'=\frac{x \left(x + 1\right) \log{\left(x \right)} + x \left(x^{2} + 1\right) \log{\left(x \right)} \operatorname{atan}{\left(x \right)} - \left(x + 1\right) \left(x^{2} + 1\right) \operatorname{atan}{\left(x \right)}}{x \left(x^{2} + 1\right) \log{\left(x \right)}^{2}}$
# $y=\operatorname{atan}{\left(\sqrt{\frac{1 - \cos{\left(x \right)}}{\cos{\left(x \right)} + 1}} \right)}$ $ \rightarrow $$y'=- \frac{\sqrt{- \frac{\cos{\left(x \right)} - 1}{\cos{\left(x \right)} + 1}} \sin{\left(x \right)}}{2 \cos{\left(x \right)} - 2}$
# $y=\frac{x \sqrt{1 - x^{2}}}{4} + \left(\frac{x^{3}}{2} - \frac{1}{4}\right) \operatorname{asin}{\left(x \right)}$ $ \rightarrow $$y'=\frac{x^{2} \left(x + 3 \sqrt{1 - x^{2}} \operatorname{asin}{\left(x \right)} - 1\right)}{2 \sqrt{1 - x^{2}}}$

# %%
df_ejercicios
# Out:
#                                        enunciado_latex  \
# 0                                              $y=2 x$
# 1                                          $y=3 x - 5$
# 2                                $y=2 x^{2} - 7 x + 5$
# 3                     $y=7 x^{5} - 3 x^{2} + x + 2345$
# 4                             $y=x \left(x + 2\right)$
# 5            $y=\left(x - 1\right) \left(x + 1\right)$
# 6    $y=\frac{5 x^{4}}{7} - \frac{x^{3}}{55} - \fra...
# 7                           $y=\left(x + 1\right)^{3}$
# 8                   $y=\left(x^{3} + x + 1\right)^{4}$
# 9    $y=- \left(3 x - 1\right)^{2} + \left(3 x + 1\...
# 10                                 $y=\frac{1}{x^{2}}$
# 11                                 $y=\frac{1}{x + 1}$
# 12                     $y=\frac{x^{2} - 3}{x^{3} + x}$
# 13                                 $y=\frac{x + 1}{x}$
# 14    $y=\frac{x \left(x^{2} - 1\right)}{3 x^{2} - 3}$
# 15                                 $y=\frac{1}{x^{3}}$
# 16                                 $y=x^{\frac{1}{2}}$
# 17                                 $y=x^{\frac{2}{3}}$
# 18                                $y=x^{\frac{-2}{3}}$
# 19   $y=x^{\frac{1}{2}} + x^{\frac{1}{5}} + x^{\fra...
# 20                               $y=\sqrt{3} \sqrt{x}$
# 21                          $y=\frac{x^{3}}{\sqrt{x}}$
# 22                           $y=x^{3} x^{\frac{1}{3}}$
# 23                              $y=\frac{\sqrt{x}}{x}$
# 24                      $y=\left(1 - x^{2}\right)^{3}$
# 25                                  $y=\sqrt{2 x - 4}$
# 26                                    $y=\sqrt{2 - x}$
# 27                     $y=\sqrt[3]{2} \sqrt[3]{x^{2}}$
# 28                              $y=\sqrt{3 x^{2} - 1}$
# 29                        $y=\frac{2 x}{\sqrt{x - 1}}$
# ..                                                 ...
# 124            $y=\sqrt[3]{\sin{\left(x^{2} \right)}}$
# 125                            $y=\sqrt{\sqrt{x} + x}$
# 126                          $y=\sqrt{x \sqrt{x + 1}}$
# 127  $y=\log{\left(\left(x \tan{\left(x \right)}\ri...
# 128  $y=\log{\left(\frac{\sqrt[3]{x^{2} - 1}}{x^{2}...
# 129  $y=\log{\left(\sqrt[4]{\frac{1}{\left(x + 1\ri...
# 130                                      $y=x^{x + 1}$
# 131  $y=\left(\frac{\sin{\left(x \right)}}{x}\right...
# 132  $y=e^{2 \operatorname{asin}{\left(x^{2} \right...
# 133            $y=e^{4 x} x^{3} \cos{\left(x \right)}$
# 134  $y=\operatorname{asin}{\left(\frac{2 x - 1}{\s...
# 135  $y=\sin{\left(x^{2} + \cos{\left(x \right)} \r...
# 136      $y=\frac{x \sin{\left(x \right)}}{e^{x} + 1}$
# 137  $y=\operatorname{atan}{\left(\frac{- 4 x^{3} +...
# 138  $y=\log{\left(\frac{\tan{\left(x - 2 \right)} ...
# 139  $y=\sqrt{\log{\left(\tan{\left(x^{2} + 1 \righ...
# 140  $y=\operatorname{asin}{\left(2 x \sqrt{1 - x^{...
# 141  $y=\left(1 - \cos{\left(x \right)}\right) \cot...
# 142  $y=\operatorname{atan}{\left(\frac{\sqrt{x^{2}...
# 143  $y=e^{\log{\left(\sin^{2}{\left(x \right)} \ri...
# 144  $y=- \operatorname{atan}{\left(x \right)} + \o...
# 145  $y=\operatorname{atan}{\left(\frac{x}{\sqrt{1 ...
# 146  $y=\cos^{\log{\left(x^{2} \right)}}{\left(x \r...
# 147  $y=\frac{4 x + 1}{\cos^{2}{\left(2 x^{2} + x +...
# 148    $y=\sin{\left(x \right)} \cos{\left(x \right)}$
# 149  $y=\sqrt[3]{\frac{\sin{\left(3 x \right)}}{1 -...
# 150  $y=\operatorname{asin}{\left(\sqrt{\frac{1 - e...
# 151  $y=\frac{\left(x + 1\right) \operatorname{atan...
# 152  $y=\operatorname{atan}{\left(\sqrt{\frac{1 - \...
# 153  $y=\frac{x \sqrt{1 - x^{2}}}{4} + \left(\frac{...
#
#                                              enunciado  \
# 0                                            diff(2*x)
# 1                                        diff(3*x - 5)
# 2                               diff(2*x**2 - 7*x + 5)
# 3                     diff(7*x**5 - 3*x**2 + x + 2345)
# 4                                      diff(x*(x + 2))
# 5                                diff((x - 1)*(x + 1))
# 6       diff(5*x**4/7 - x**3/55 - 3*x**2/4 + x - 1255)
# 7                                     diff((x + 1)**3)
# 8                              diff((x**3 + x + 1)**4)
# 9                   diff(-(3*x - 1)**2 + (3*x + 1)**2)
# 10                                       diff(x**(-2))
# 11                                     diff(1/(x + 1))
# 12                         diff((x**2 - 3)/(x**3 + x))
# 13                                     diff((x + 1)/x)
# 14                     diff(x*(x**2 - 1)/(3*x**2 - 3))
# 15                                       diff(x**(-3))
# 16                                       diff(sqrt(x))
# 17                                      diff(x**(2/3))
# 18                                     diff(x**(-2/3))
# 19                 diff(x**(1/6) + x**(1/5) + sqrt(x))
# 20                               diff(sqrt(3)*sqrt(x))
# 21                                      diff(x**(5/2))
# 22                                     diff(x**(10/3))
# 23                                     diff(1/sqrt(x))
# 24                                 diff((1 - x**2)**3)
# 25                                 diff(sqrt(2*x - 4))
# 26                                   diff(sqrt(2 - x))
# 27                        diff(2**(1/3)*(x**2)**(1/3))
# 28                              diff(sqrt(3*x**2 - 1))
# 29                               diff(2*x/sqrt(x - 1))
# ..                                                 ...
# 124                             diff(sin(x**2)**(1/3))
# 125                            diff(sqrt(sqrt(x) + x))
# 126                          diff(sqrt(x*sqrt(x + 1)))
# 127                          diff(log(x**2*tan(x)**2))
# 128                  diff(log((x**2 - 1)**(1/3)/x**2))
# 129                  diff(log(((x + 1)**(-2))**(1/4)))
# 130                                   diff(x**(x + 1))
# 131                                diff((sin(x)/x)**x)
# 132                            diff(exp(2*asin(x**2)))
# 133                         diff(x**3*exp(4*x)*cos(x))
# 134                    diff(asin(sqrt(5)*(2*x - 1)/5))
# 135                           diff(sin(x**2 + cos(x)))
# 136                        diff(x*sin(x)/(exp(x) + 1))
# 137    diff(atan((-4*x**3 + 4*x)/(x**4 - 6*x**2 + 1)))
# 138     diff(log((tan(x - 2) - 2)/(2*tan(x - 2) - 1)))
# 139                     diff(sqrt(log(tan(x**2 + 1))))
# 140                     diff(asin(2*x*sqrt(1 - x**2)))
# 141                          diff((1 - cos(x))*cot(x))
# 142                 diff(atan((sqrt(x**2 + 1) - 1)/x))
# 143                                    diff(sin(x)**2)
# 144             diff(-atan(x) + atan((x + 1)/(1 - x)))
# 145                       diff(atan(x/sqrt(1 - x**2)))
# 146                            diff(cos(x)**log(x**2))
# 147             diff((4*x + 1)/cos(2*x**2 + x + 1)**2)
# 148                                diff(sin(x)*cos(x))
# 149               diff((sin(3*x)/(1 - sin(x)))**(1/3))
# 150        diff(asin(sqrt((1 - exp(x))/(exp(x) + 1))))
# 151                       diff((x + 1)*atan(x)/log(x))
# 152        diff(atan(sqrt((1 - cos(x))/(cos(x) + 1))))
# 153  diff(x*sqrt(1 - x**2)/4 + (x**3/2 - 1/4)*asin(x))
#
#                                               solucion  \
# 0                                               $y'=2$
# 1                                               $y'=3$
# 2                                         $y'=4 x - 7$
# 3                              $y'=35 x^{4} - 6 x + 1$
# 4                                         $y'=2 x + 2$
# 5                                             $y'=2 x$
# 6    $y'=\frac{20 x^{3}}{7} - \frac{3 x^{2}}{55} - ...
# 7                        $y'=3 \left(x + 1\right)^{2}$
# 8    $y'=\left(12 x^{2} + 4\right) \left(x^{3} + x ...
# 9                                              $y'=12$
# 10                              $y'=- \frac{2}{x^{3}}$
# 11             $y'=- \frac{1}{\left(x + 1\right)^{2}}$
# 12   $y'=\frac{- x^{4} + 10 x^{2} + 3}{x^{2} \left(...
# 13                              $y'=- \frac{1}{x^{2}}$
# 14                                    $y'=\frac{1}{3}$
# 15                              $y'=- \frac{3}{x^{4}}$
# 16                           $y'=\frac{1}{2 \sqrt{x}}$
# 17                        $y'=\frac{2}{3 \sqrt[3]{x}}$
# 18                  $y'=- \frac{2}{3 x^{\frac{5}{3}}}$
# 19   $y'=\frac{\frac{x^{\frac{49}{30}}}{2} + \frac{...
# 20                    $y'=\frac{\sqrt{3}}{2 \sqrt{x}}$
# 21                    $y'=\frac{5 x^{\frac{3}{2}}}{2}$
# 22                   $y'=\frac{10 x^{\frac{7}{3}}}{3}$
# 23                  $y'=- \frac{1}{2 x^{\frac{3}{2}}}$
# 24               $y'=- 6 x \left(x^{2} - 1\right)^{2}$
# 25                $y'=\frac{\sqrt{2}}{2 \sqrt{x - 2}}$
# 26                     $y'=- \frac{1}{2 \sqrt{2 - x}}$
# 27      $y'=\frac{2 \sqrt[3]{2} \sqrt[3]{x^{2}}}{3 x}$
# 28                 $y'=\frac{3 x}{\sqrt{3 x^{2} - 1}}$
# 29   $y'=\frac{x - 2}{\left(x - 1\right)^{\frac{3}{...
# ..                                                 ...
# 124  $y'=\frac{2 x \cos{\left(x^{2} \right)}}{3 \si...
# 125  $y'=\frac{2 \sqrt{x} + 1}{4 \sqrt{x} \sqrt{\sq...
# 126  $y'=\frac{\sqrt{x \sqrt{x + 1}} \left(3 x + 2\...
# 127  $y'=\frac{4}{\sin{\left(2 x \right)}} + \frac{...
# 128  $y'=\frac{2 \left(3 - 2 x^{2}\right)}{3 x \lef...
# 129                           $y'=- \frac{1}{2 x + 2}$
# 130  $y'=x^{x} \left(x \log{\left(x \right)} + x + ...
# 131  $y'=\left(\frac{\sin{\left(x \right)}}{x}\righ...
# 132  $y'=\frac{4 x e^{2 \operatorname{asin}{\left(x...
# 133  $y'=x^{2} \left(- x \sin{\left(x \right)} + 4 ...
# 134              $y'=\frac{1}{\sqrt{- x^{2} + x + 1}}$
# 135  $y'=\left(2 x - \sin{\left(x \right)}\right) \...
# 136  $y'=\frac{- x e^{x} \sin{\left(x \right)} + \l...
# 137                           $y'=\frac{4}{x^{2} + 1}$
# 138  $y'=\frac{3 \left(\tan^{2}{\left(x - 2 \right)...
# 139  $y'=\frac{x \left(\tan^{2}{\left(x^{2} + 1 \ri...
# 140  $y'=\frac{2 \left(1 - 2 x^{2}\right)}{\sqrt{1 ...
# 141  $y'=\frac{\cos{\left(x \right)} - 1}{\sin^{2}{...
# 142            $y'=\frac{1}{2 \left(x^{2} + 1\right)}$
# 143                       $y'=\sin{\left(2 x \right)}$
# 144                                             $y'=0$
# 145                    $y'=\frac{1}{\sqrt{1 - x^{2}}}$
# 146  $y'=\frac{\left(- x \log{\left(x^{2} \right)} ...
# 147  $y'=\frac{2 \left(\left(4 x + 1\right)^{2} \si...
# 148                       $y'=\cos{\left(2 x \right)}$
# 149  $y'=- \frac{\sqrt[3]{- \frac{\sin{\left(3 x \r...
# 150  $y'=\frac{\sqrt{2} \sqrt{- \tanh{\left(\frac{x...
# 151  $y'=\frac{x \left(x + 1\right) \log{\left(x \r...
# 152  $y'=- \frac{\sqrt{- \frac{\cos{\left(x \right)...
# 153  $y'=\frac{x^{2} \left(x + 3 \sqrt{1 - x^{2}} \...
#
#                                    texto curso     titulo n_ejercicio  \
# 0    Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 1    Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 2    Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 3    Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 4    Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 5    Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 6    Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 7    Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 8    Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 9    Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 10   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 11   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 12   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 13   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 14   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 15   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 16   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 17   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 18   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 19   Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 20   Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 21   Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 22   Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 23   Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 24   Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 25   Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 26   Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 27   Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 28   Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 29   Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# ..                                   ...   ...        ...         ...
# 124  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 125  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 126  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 127  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 128  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 129  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 130  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 131  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 132  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 133  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 134  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 135  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 136  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 137  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 138  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 139  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 140  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 141  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 142  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 143  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 144  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 145  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 146  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 147  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 148  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 149  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 150  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 151  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 152  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 153  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
#
#     dificultad n_columnas puntos  enun_tex  sol_tex
# 0            5          2      1     False    False
# 1            5          2      1     False    False
# 2            5          2      1     False    False
# 3            5          2      1     False    False
# 4            5          2      1     False    False
# 5            5          2      1     False    False
# 6            5          2      1     False    False
# 7            5          2      1     False    False
# 8            5          2      1     False    False
# 9            5          2      1     False    False
# 10           5          2      1     False    False
# 11           5          2      1     False    False
# 12           5          2      1     False    False
# 13           5          2      1     False    False
# 14           5          2      1     False    False
# 15           5          2      1     False    False
# 16           5          2      1     False    False
# 17           5          2      1     False    False
# 18           5          2      1     False    False
# 19           5          2      1     False    False
# 20           5          2      1     False    False
# 21           5          2      1     False    False
# 22           5          2      1     False    False
# 23           5          2      1     False    False
# 24           5          2      1     False    False
# 25           5          2      1     False    False
# 26           5          2      1     False    False
# 27           5          2      1     False    False
# 28           5          2      1     False    False
# 29           5          2      1     False    False
# ..         ...        ...    ...       ...      ...
# 124          5          2      1     False    False
# 125          5          2      1     False    False
# 126          5          2      1     False    False
# 127          5          2      1     False    False
# 128          5          2      1     False    False
# 129          5          2      1     False    False
# 130          5          2      1     False    False
# 131          5          2      1     False    False
# 132          5          2      1     False    False
# 133          5          1      1     False    False
# 134          5          1      1     False    False
# 135          5          1      1     False    False
# 136          5          1      1     False    False
# 137          5          1      1     False    False
# 138          5          1      1     False    False
# 139          5          1      1     False    False
# 140          5          1      1     False    False
# 141          5          1      1     False    False
# 142          5          1      1     False    False
# 143          5          1      1     False    False
# 144          5          1      1     False    False
# 145          5          1      1     False    False
# 146          5          1      1     False    False
# 147          5          1      1     False    False
# 148          5          1      1     False    False
# 149          5          1      1     False    False
# 150          5          1      1     False    False
# 151          5          1      1     False    False
# 152          5          1      1     False    False
# 153          5          1      1     False    False
#
# [154 rows x 12 columns]

# %%
escribir_preambulo(fichero, titulo, 'ejercicios')
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **p25e16
#                                       enunciado_latex  \
# 0                                             $y=2 x$
# 1                                         $y=3 x - 5$
# 2                               $y=2 x^{2} - 7 x + 5$
# 3                    $y=7 x^{5} - 3 x^{2} + x + 2345$
# 4                            $y=x \left(x + 2\right)$
# 5           $y=\left(x - 1\right) \left(x + 1\right)$
# 6   $y=\frac{5 x^{4}}{7} - \frac{x^{3}}{55} - \fra...
# 7                          $y=\left(x + 1\right)^{3}$
# 8                  $y=\left(x^{3} + x + 1\right)^{4}$
# 9   $y=- \left(3 x - 1\right)^{2} + \left(3 x + 1\...
# 10                                $y=\frac{1}{x^{2}}$
# 11                                $y=\frac{1}{x + 1}$
# 12                    $y=\frac{x^{2} - 3}{x^{3} + x}$
# 13                                $y=\frac{x + 1}{x}$
# 14   $y=\frac{x \left(x^{2} - 1\right)}{3 x^{2} - 3}$
# 15                                $y=\frac{1}{x^{3}}$
# 16                                $y=x^{\frac{1}{2}}$
# 17                                $y=x^{\frac{2}{3}}$
# 18                               $y=x^{\frac{-2}{3}}$
#
#                                          enunciado  \
# 0                                        diff(2*x)
# 1                                    diff(3*x - 5)
# 2                           diff(2*x**2 - 7*x + 5)
# 3                 diff(7*x**5 - 3*x**2 + x + 2345)
# 4                                  diff(x*(x + 2))
# 5                            diff((x - 1)*(x + 1))
# 6   diff(5*x**4/7 - x**3/55 - 3*x**2/4 + x - 1255)
# 7                                 diff((x + 1)**3)
# 8                          diff((x**3 + x + 1)**4)
# 9               diff(-(3*x - 1)**2 + (3*x + 1)**2)
# 10                                   diff(x**(-2))
# 11                                 diff(1/(x + 1))
# 12                     diff((x**2 - 3)/(x**3 + x))
# 13                                 diff((x + 1)/x)
# 14                 diff(x*(x**2 - 1)/(3*x**2 - 3))
# 15                                   diff(x**(-3))
# 16                                   diff(sqrt(x))
# 17                                  diff(x**(2/3))
# 18                                 diff(x**(-2/3))
#
#                                              solucion  \
# 0                                              $y'=2$
# 1                                              $y'=3$
# 2                                        $y'=4 x - 7$
# 3                             $y'=35 x^{4} - 6 x + 1$
# 4                                        $y'=2 x + 2$
# 5                                            $y'=2 x$
# 6   $y'=\frac{20 x^{3}}{7} - \frac{3 x^{2}}{55} - ...
# 7                       $y'=3 \left(x + 1\right)^{2}$
# 8   $y'=\left(12 x^{2} + 4\right) \left(x^{3} + x ...
# 9                                             $y'=12$
# 10                             $y'=- \frac{2}{x^{3}}$
# 11            $y'=- \frac{1}{\left(x + 1\right)^{2}}$
# 12  $y'=\frac{- x^{4} + 10 x^{2} + 3}{x^{2} \left(...
# 13                             $y'=- \frac{1}{x^{2}}$
# 14                                   $y'=\frac{1}{3}$
# 15                             $y'=- \frac{3}{x^{4}}$
# 16                          $y'=\frac{1}{2 \sqrt{x}}$
# 17                       $y'=\frac{2}{3 \sqrt[3]{x}}$
# 18                 $y'=- \frac{2}{3 x^{\frac{5}{3}}}$
#
#                                   texto curso     titulo n_ejercicio  \
# 0   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 1   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 2   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 3   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 4   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 5   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 6   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 7   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 8   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 9   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 10  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 11  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 12  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 13  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 14  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 15  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 16  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 17  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 18  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 0           5          2      1     False    False
# 1           5          2      1     False    False
# 2           5          2      1     False    False
# 3           5          2      1     False    False
# 4           5          2      1     False    False
# 5           5          2      1     False    False
# 6           5          2      1     False    False
# 7           5          2      1     False    False
# 8           5          2      1     False    False
# 9           5          2      1     False    False
# 10          5          2      1     False    False
# 11          5          2      1     False    False
# 12          5          2      1     False    False
# 13          5          2      1     False    False
# 14          5          2      1     False    False
# 15          5          2      1     False    False
# 16          5          2      1     False    False
# 17          5          2      1     False    False
# 18          5          2      1     False    False
# **Ejercicio: **p25e16cont
#                                       enunciado_latex  \
# 19  $y=x^{\frac{1}{2}} + x^{\frac{1}{5}} + x^{\fra...
# 20                              $y=\sqrt{3} \sqrt{x}$
# 21                         $y=\frac{x^{3}}{\sqrt{x}}$
# 22                          $y=x^{3} x^{\frac{1}{3}}$
# 23                             $y=\frac{\sqrt{x}}{x}$
# 24                     $y=\left(1 - x^{2}\right)^{3}$
# 25                                 $y=\sqrt{2 x - 4}$
# 26                                   $y=\sqrt{2 - x}$
# 27                    $y=\sqrt[3]{2} \sqrt[3]{x^{2}}$
# 28                             $y=\sqrt{3 x^{2} - 1}$
# 29                       $y=\frac{2 x}{\sqrt{x - 1}}$
# 30                                       $y=\sqrt{1}$
# 31                                        $y=e^{2 x}$
# 32                                        $y=2^{5 x}$
# 33                                $y=8^{3 x^{2} - 1}$
# 34                                    $y=a^{x} x^{a}$
# 35                                   $y=e^{\sqrt{x}}$
# 36  $y=\frac{\log{\left(2 x - 1 \right)}}{\log{\le...
# 37                      $y=\log{\left(x + 3 \right)}$
#
#                               enunciado  \
# 19  diff(x**(1/6) + x**(1/5) + sqrt(x))
# 20                diff(sqrt(3)*sqrt(x))
# 21                       diff(x**(5/2))
# 22                      diff(x**(10/3))
# 23                      diff(1/sqrt(x))
# 24                  diff((1 - x**2)**3)
# 25                  diff(sqrt(2*x - 4))
# 26                    diff(sqrt(2 - x))
# 27         diff(2**(1/3)*(x**2)**(1/3))
# 28               diff(sqrt(3*x**2 - 1))
# 29                diff(2*x/sqrt(x - 1))
# 30                              diff(1)
# 31                       diff(exp(2*x))
# 32                       diff(2**(5*x))
# 33                diff(8**(3*x**2 - 1))
# 34                      diff(a**x*x**a)
# 35                   diff(exp(sqrt(x)))
# 36           diff(log(2*x - 1)/log(10))
# 37                     diff(log(x + 3))
#
#                                              solucion  \
# 19  $y'=\frac{\frac{x^{\frac{49}{30}}}{2} + \frac{...
# 20                   $y'=\frac{\sqrt{3}}{2 \sqrt{x}}$
# 21                   $y'=\frac{5 x^{\frac{3}{2}}}{2}$
# 22                  $y'=\frac{10 x^{\frac{7}{3}}}{3}$
# 23                 $y'=- \frac{1}{2 x^{\frac{3}{2}}}$
# 24              $y'=- 6 x \left(x^{2} - 1\right)^{2}$
# 25               $y'=\frac{\sqrt{2}}{2 \sqrt{x - 2}}$
# 26                    $y'=- \frac{1}{2 \sqrt{2 - x}}$
# 27     $y'=\frac{2 \sqrt[3]{2} \sqrt[3]{x^{2}}}{3 x}$
# 28                $y'=\frac{3 x}{\sqrt{3 x^{2} - 1}}$
# 29  $y'=\frac{x - 2}{\left(x - 1\right)^{\frac{3}{...
# 30                                             $y'=0$
# 31                                     $y'=2 e^{2 x}$
# 32                 $y'=32^{x} \log{\left(32 \right)}$
# 33  $y'=9 \cdot 2^{9 x^{2} - 2} x \log{\left(2 \ri...
# 34  $y'=a^{x} x^{a - 1} \left(a + x \log{\left(a \...
# 35               $y'=\frac{e^{\sqrt{x}}}{2 \sqrt{x}}$
# 36  $y'=\frac{2}{\left(2 x - 1\right) \log{\left(1...
# 37                               $y'=\frac{1}{x + 3}$
#
#                                   texto curso     titulo n_ejercicio  \
# 19  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 20  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 21  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 22  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 23  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 24  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 25  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 26  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 27  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 28  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 29  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 30  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 31  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 32  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 33  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 34  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 35  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 36  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 37  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 19          5          2      1     False    False
# 20          5          2      1     False    False
# 21          5          2      1     False    False
# 22          5          2      1     False    False
# 23          5          2      1     False    False
# 24          5          2      1     False    False
# 25          5          2      1     False    False
# 26          5          2      1     False    False
# 27          5          2      1     False    False
# 28          5          2      1     False    False
# 29          5          2      1     False    False
# 30          5          2      1     False    False
# 31          5          2      1     False    False
# 32          5          2      1     False    False
# 33          5          2      1     False    False
# 34          5          2      1     False    False
# 35          5          2      1     False    False
# 36          5          2      1     False    False
# 37          5          2      1     False    False
# **Ejercicio: **p25e17
#                                       enunciado_latex  \
# 38                $y=\log{\left(3 x^{2} - 7 \right)}$
# 39     $y=\log{\left(\left(x - 2\right)^{2} \right)}$
# 40  $y=\frac{\log{\left(x^{2} - 2 x \right)}}{\log...
# 41  $y=\frac{\log{\left(2 x^{3} + 3 x^{2} \right)}...
# 42                   $y=\sqrt{\log{\left(x \right)}}$
# 43                $y=\frac{\log{\left(x \right)}}{x}$
# 44        $y=\log{\left(\frac{1 - x}{x + 1} \right)}$
# 45            $y=\log{\left(\sqrt[4]{x^{3}} \right)}$
# 46  $y=\frac{\log{\left(2 x + 1 \right)}}{\log{\le...
# 47    $y=\log{\left(\frac{e^{x}}{e^{x} - 1} \right)}$
# 48  $y=\frac{1 - \log{\left(x \right)}}{\log{\left...
# 49                            $y=\frac{e^{x}}{x - 1}$
# 50        $y=\frac{e^{x} - e^{- x}}{e^{x} + e^{- x}}$
# 51                           $y=e^{\sqrt{x^{2} + 1}}$
# 52                        $y=\sin{\left(2 x \right)}$
# 53                    $y=\sin{\left(7 x - 3 \right)}$
# 54                        $y=\cos{\left(5 x \right)}$
# 55                      $y=3 \tan{\left(2 x \right)}$
# 56                      $y=\sin^{2}{\left(x \right)}$
# 57                      $y=\sin{\left(x^{2} \right)}$
#
#                                       enunciado  \
# 38                        diff(log(3*x**2 - 7))
# 39                        diff(log((x - 2)**2))
# 40                diff(log(x**2 - 2*x)/log(10))
# 41            diff(log(2*x**3 + 3*x**2)/log(2))
# 42                           diff(sqrt(log(x)))
# 43                               diff(log(x)/x)
# 44                   diff(log((1 - x)/(x + 1)))
# 45                     diff(log((x**3)**(1/4)))
# 46                    diff(log(2*x + 1)/log(4))
# 47               diff(log(exp(x)/(exp(x) - 1)))
# 48              diff((1 - log(x))/(log(x) + 1))
# 49                         diff(exp(x)/(x - 1))
# 50  diff((exp(x) - exp(-x))/(exp(x) + exp(-x)))
# 51                    diff(exp(sqrt(x**2 + 1)))
# 52                               diff(sin(2*x))
# 53                           diff(sin(7*x - 3))
# 54                               diff(cos(5*x))
# 55                             diff(3*tan(2*x))
# 56                              diff(sin(x)**2)
# 57                              diff(sin(x**2))
#
#                                              solucion  \
# 38                       $y'=\frac{6 x}{3 x^{2} - 7}$
# 39                               $y'=\frac{2}{x - 2}$
# 40  $y'=\frac{2 \left(x - 1\right)}{x \left(x - 2\...
# 41  $y'=\frac{6 \left(x + 1\right)}{x \left(2 x + ...
# 42    $y'=\frac{1}{2 x \sqrt{\log{\left(x \right)}}}$
# 43       $y'=\frac{1 - \log{\left(x \right)}}{x^{2}}$
# 44                           $y'=\frac{2}{x^{2} - 1}$
# 45                                 $y'=\frac{3}{4 x}$
# 46  $y'=\frac{1}{\left(2 x + 1\right) \log{\left(2...
# 47                           $y'=\frac{1}{1 - e^{x}}$
# 48  $y'=- \frac{2}{x \left(\log{\left(x \right)} +...
# 49  $y'=\frac{\left(x - 2\right) e^{x}}{x^{2} - 2 ...
# 50     $y'=\frac{4 e^{2 x}}{e^{4 x} + 2 e^{2 x} + 1}$
# 51  $y'=\frac{x e^{\sqrt{x^{2} + 1}}}{\sqrt{x^{2} ...
# 52                     $y'=2 \cos{\left(2 x \right)}$
# 53                 $y'=7 \cos{\left(7 x - 3 \right)}$
# 54                   $y'=- 5 \sin{\left(5 x \right)}$
# 55         $y'=\frac{6}{\cos^{2}{\left(2 x \right)}}$
# 56                       $y'=\sin{\left(2 x \right)}$
# 57                 $y'=2 x \cos{\left(x^{2} \right)}$
#
#                                   texto curso     titulo n_ejercicio  \
# 38  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 39  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 40  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 41  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 42  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 43  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 44  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 45  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 46  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 47  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 48  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 49  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 50  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 51  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 52  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 53  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 54  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 55  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 56  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 57  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 38          5          2      1     False    False
# 39          5          2      1     False    False
# 40          5          2      1     False    False
# 41          5          2      1     False    False
# 42          5          2      1     False    False
# 43          5          2      1     False    False
# 44          5          2      1     False    False
# 45          5          2      1     False    False
# 46          5          2      1     False    False
# 47          5          2      1     False    False
# 48          5          2      1     False    False
# 49          5          2      1     False    False
# 50          5          2      1     False    False
# 51          5          2      1     False    False
# 52          5          2      1     False    False
# 53          5          2      1     False    False
# 54          5          2      1     False    False
# 55          5          2      1     False    False
# 56          5          2      1     False    False
# 57          5          2      1     False    False
# **Ejercicio: **p25e17cont
#                                       enunciado_latex  \
# 58              $y=\cos^{2}{\left(x^{2} + 1 \right)}$
# 59                    $y=\tan^{3}{\left(5 x \right)}$
# 60                    $y=\sin^{3}{\left(4 x \right)}$
# 61                 $y=\sqrt{\sin{\left(2 x \right)}}$
# 62  $y=\log{\left(- \tan{\left(x - 1 \right)} \rig...
# 63                $y=\sqrt[3]{\sin{\left(x \right)}}$
# 64  $y=\sin^{3}{\left(x \right)} \cos{\left(x \rig...
# 65                    $y=\sec{\left(5 x + 2 \right)}$
# 66         $y=\operatorname{asin}{\left(2 x \right)}$
# 67       $y=\operatorname{acos}{\left(x^{2} \right)}$
# 68  $y=\operatorname{atan}{\left(\frac{x - 1}{1 - ...
# 69  $y=\operatorname{asin}{\left(\frac{x + 1}{x - ...
# 70  $y=\tan^{2}{\left(\sin{\left(x \right)} \right)}$
# 71            $y=\sin^{\frac{1}{x}}{\left(x \right)}$
# 72                      $y=x^{\tan{\left(x \right)}}$
# 73  $y=2^{\log{\left(\cos{\left(x \right)} \right)}}$
# 74  $y=\sin^{\operatorname{atan}{\left(x \right)}}...
# 75       $y=\operatorname{atan}^{x}{\left(x \right)}$
# 76                      $y=x^{\sec{\left(x \right)}}$
#
#                       enunciado  \
# 58       diff(cos(x**2 + 1)**2)
# 59            diff(tan(5*x)**3)
# 60            diff(sin(4*x)**3)
# 61         diff(sqrt(sin(2*x)))
# 62       diff(log(-tan(x - 1)))
# 63          diff(sin(x)**(1/3))
# 64       diff(sin(x)**3*cos(x))
# 65           diff(sec(5*x + 2))
# 66              diff(asin(2*x))
# 67             diff(acos(x**2))
# 68  diff(atan((x - 1)/(1 - x)))
# 69  diff(asin((x + 1)/(x - 1)))
# 70         diff(tan(sin(x))**2)
# 71          diff(sin(x)**(1/x))
# 72              diff(x**tan(x))
# 73         diff(2**log(cos(x)))
# 74        diff(sin(x)**atan(x))
# 75             diff(atan(x)**x)
# 76              diff(x**sec(x))
#
#                                              solucion  \
# 58         $y'=- 2 x \sin{\left(2 x^{2} + 2 \right)}$
# 59  $y'=\frac{15 \tan^{2}{\left(5 x \right)}}{\cos...
# 60  $y'=12 \sin^{2}{\left(4 x \right)} \cos{\left(...
# 61  $y'=\frac{\cos{\left(2 x \right)}}{\sqrt{\sin{...
# 62  $y'=\tan{\left(x - 1 \right)} + \frac{1}{\tan{...
# 63  $y'=\frac{\cos{\left(x \right)}}{3 \sin^{\frac...
# 64  $y'=\left(3 - 4 \sin^{2}{\left(x \right)}\righ...
# 65  $y'=5 \tan{\left(5 x + 2 \right)} \sec{\left(5...
# 66                  $y'=\frac{2}{\sqrt{1 - 4 x^{2}}}$
# 67                $y'=- \frac{2 x}{\sqrt{1 - x^{4}}}$
# 68                                             $y'=0$
# 69  $y'=- \frac{1}{\sqrt{- \frac{x}{x^{2} - 2 x + ...
# 70  $y'=\frac{2 \cos{\left(x \right)} \tan{\left(\...
# 71  $y'=\frac{\left(x \cos{\left(x \right)} - \log...
# 72  $y'=x^{\tan{\left(x \right)} - 1} \left(\frac{...
# 73  $y'=- 2^{\log{\left(\cos{\left(x \right)} \rig...
# 74  $y'=\frac{\left(\left(x^{2} + 1\right) \cos{\l...
# 75  $y'=\frac{\left(x + \left(x^{2} + 1\right) \lo...
# 76  $y'=x^{\sec{\left(x \right)} - 1} \left(x \log...
#
#                                   texto curso     titulo n_ejercicio  \
# 58  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 59  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 60  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 61  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 62  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 63  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 64  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 65  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 66  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 67  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 68  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 69  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 70  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 71  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 72  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 73  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 74  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 75  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 76  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 58          5          1      1     False    False
# 59          5          1      1     False    False
# 60          5          1      1     False    False
# 61          5          1      1     False    False
# 62          5          1      1     False    False
# 63          5          1      1     False    False
# 64          5          1      1     False    False
# 65          5          1      1     False    False
# 66          5          1      1     False    False
# 67          5          1      1     False    False
# 68          5          1      1     False    False
# 69          5          1      1     False    False
# 70          5          1      1     False    False
# 71          5          1      1     False    False
# 72          5          1      1     False    False
# 73          5          1      1     False    False
# 74          5          1      1     False    False
# 75          5          1      1     False    False
# 76          5          1      1     False    False
# **Ejercicio: **p26e18
#                                       enunciado_latex  \
# 77                     $y=\left(x^{2} - 3\right)^{4}$
# 78                       $y=\left(1 - 5 x\right)^{6}$
# 79                    $y=\sqrt[3]{3} \sqrt[3]{x^{2}}$
# 80  $y=\left(x^{2} + 4\right) \left(3 x^{3} + 1\ri...
# 81                 $y=\sqrt{2} \sqrt{x} + 2 \sqrt{x}$
# 82  $y=\log{\left(\frac{x^{4}}{\left(3 x + 4\right...
# 83  $y=\log{\left(\sqrt{\frac{x - 1}{x + 1}} \righ...
# 84     $y=\log{\left(\left(x + 3\right)^{2} \right)}$
# 85                $y=x^{2} \log{\left(x \right)} - x$
# 86  $y=\log{\left(\left(x^{2} + 1\right) \left(2 x...
# 87       $y=\log{\left(x + \sqrt{x^{2} + 1} \right)}$
# 88                    $y=x^{2} \sin{\left(x \right)}$
# 89   $y=\operatorname{asin}{\left(x^{2} + x \right)}$
# 90  $y=x^{2} \operatorname{acos}{\left(\frac{2}{x}...
# 91  $y=\log{\left(\frac{e^{x} - 1}{2 e^{x}} \right)}$
# 92            $y=\frac{\log{\left(x^{2} \right)}}{x}$
# 93                            $y=2^{x^{2} + 3 x + 1}$
# 94                                    $y=2^{x^{2}} x$
# 95                      $y=2^{\sin{\left(x \right)}}$
# 96                      $y=e^{\tan{\left(x \right)}}$
#
#                                    enunciado  \
# 77                       diff((x**2 - 3)**4)
# 78                        diff((1 - 5*x)**6)
# 79              diff(3**(1/3)*(x**2)**(1/3))
# 80             diff((x**2 + 4)*(3*x**3 + 1))
# 81         diff(sqrt(2)*sqrt(x) + 2*sqrt(x))
# 82              diff(log(x**4/(3*x + 4)**3))
# 83          diff(log(sqrt((x - 1)/(x + 1))))
# 84                     diff(log((x + 3)**2))
# 85                     diff(x**2*log(x) - x)
# 86  diff(log((x**2 + 1)*(2*x**2 + 3*x + 1)))
# 87             diff(log(x + sqrt(x**2 + 1)))
# 88                         diff(x**2*sin(x))
# 89                      diff(asin(x**2 + x))
# 90                      diff(x**2*acos(2/x))
# 91         diff(log((exp(x) - 1)*exp(-x)/2))
# 92                         diff(log(x**2)/x)
# 93                 diff(2**(x**2 + 3*x + 1))
# 94                         diff(2**(x**2)*x)
# 95                           diff(2**sin(x))
# 96                         diff(exp(tan(x)))
#
#                                              solucion  \
# 77                $y'=8 x \left(x^{2} - 3\right)^{3}$
# 78                   $y'=30 \left(5 x - 1\right)^{5}$
# 79     $y'=\frac{2 \sqrt[3]{3} \sqrt[3]{x^{2}}}{3 x}$
# 80            $y'=x \left(15 x^{3} + 36 x + 2\right)$
# 81               $y'=\frac{\sqrt{2} + 2}{2 \sqrt{x}}$
# 82       $y'=\frac{3 x + 16}{x \left(3 x + 4\right)}$
# 83                           $y'=\frac{1}{x^{2} - 1}$
# 84                               $y'=\frac{2}{x + 3}$
# 85             $y'=2 x \log{\left(x \right)} + x - 1$
# 86  $y'=\frac{8 x^{3} + 9 x^{2} + 6 x + 3}{2 x^{4}...
# 87                    $y'=\frac{1}{\sqrt{x^{2} + 1}}$
# 88  $y'=x \left(x \cos{\left(x \right)} + 2 \sin{\...
# 89  $y'=\frac{2 x + 1}{\sqrt{- x^{2} \left(x + 1\r...
# 90  $y'=2 x \operatorname{acos}{\left(\frac{2}{x} ...
# 91                           $y'=\frac{1}{e^{x} - 1}$
# 92   $y'=\frac{2 - \log{\left(x^{2} \right)}}{x^{2}}$
# 93  $y'=2^{x \left(x + 3\right)} \left(2 x + 3\rig...
# 94  $y'=2^{x^{2}} \left(x^{2} \log{\left(4 \right)...
# 95  $y'=2^{\sin{\left(x \right)}} \log{\left(2 \ri...
# 96  $y'=\frac{e^{\tan{\left(x \right)}}}{\cos^{2}{...
#
#                                   texto curso     titulo n_ejercicio  \
# 77  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 78  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 79  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 80  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 81  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 82  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 83  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 84  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 85  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 86  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 87  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 88  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 89  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 90  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 91  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 92  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 93  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 94  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 95  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 96  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 77          5          2      1     False    False
# 78          5          2      1     False    False
# 79          5          2      1     False    False
# 80          5          2      1     False    False
# 81          5          2      1     False    False
# 82          5          2      1     False    False
# 83          5          2      1     False    False
# 84          5          2      1     False    False
# 85          5          2      1     False    False
# 86          5          2      1     False    False
# 87          5          2      1     False    False
# 88          5          2      1     False    False
# 89          5          2      1     False    False
# 90          5          2      1     False    False
# 91          5          2      1     False    False
# 92          5          2      1     False    False
# 93          5          2      1     False    False
# 94          5          2      1     False    False
# 95          5          2      1     False    False
# 96          5          2      1     False    False
# **Ejercicio: **p26e18cont
#                                        enunciado_latex  \
# 97                       $y=x^{\log{\left(x \right)}}$
# 98                                 $y=x^{\frac{1}{x}}$
# 99   $y=\cos^{\sin{\left(x \right)}}{\left(x \right)}$
# 100                  $y=\sin^{3}{\left(x^{3} \right)}$
# 101  $y=\operatorname{asin}{\left(\cos{\left(x \rig...
# 102  $y=\operatorname{asin}{\left(\log{\left(x \rig...
# 103  $y=3 \sin^{2}{\left(\left(2 x + 1\right)^{3} \...
# 104  $y=\log{\left(\cos^{2}{\left(x^{2} \right)} \r...
# 105  $y=\log{\left(\sqrt{\frac{\sin{\left(2 x \righ...
# 106  $y=\log{\left(\frac{1 - \cos{\left(x \right)}}...
# 107  $y=\frac{\log{\left(\tan{\left(\frac{x}{2} \ri...
# 108  $y=\frac{\sin{\left(x \right)} + \cos{\left(x ...
# 109  $y=a^{2} \operatorname{asin}{\left(\frac{x}{a}...
# 110  $y=- \frac{\log{\left(\tan{\left(\frac{x}{2} \...
# 111  $y=e^{x} \left(x - 1\right) \left(\frac{\sin{\...
#
#                                              enunciado  \
# 97                                     diff(x**log(x))
# 98                                      diff(x**(1/x))
# 99                                diff(cos(x)**sin(x))
# 100                                 diff(sin(x**3)**3)
# 101                                 diff(asin(cos(x)))
# 102                                 diff(asin(log(x)))
# 103                       diff(3*sin((2*x + 1)**3)**2)
# 104                            diff(log(cos(x**2)**2))
# 105     diff(log(sqrt((sin(2*x) + 1)/(1 - sin(2*x)))))
# 106               diff(log((1 - cos(x))/(cos(x) + 1)))
# 107                              diff(log(tan(x/2))/2)
# 108          diff((sin(x) + cos(x))/(sin(x) - cos(x)))
# 109         diff(a**2*asin(x/a) + x*sqrt(a**2 - x**2))
# 110      diff(-log(tan(x/2))/2 + cos(x)/(2*sin(x)**2))
# 111  diff((x - 1)*(sin(log(x))/2 + cos(log(x)))*exp...
#
#                                               solucion  \
# 97   $y'=2 x^{\log{\left(x \right)} - 1} \log{\left...
# 98   $y'=x^{-2 + \frac{1}{x}} \left(1 - \log{\left(...
# 99   $y'=\left(\log{\left(\cos{\left(x \right)} \ri...
# 100  $y'=9 x^{2} \sin^{2}{\left(x^{3} \right)} \cos...
# 101  $y'=- \frac{\sin{\left(x \right)}}{\sqrt{\sin^...
# 102  $y'=\frac{1}{x \sqrt{1 - \log{\left(x \right)}...
# 103  $y'=36 \left(2 x + 1\right)^{2} \sin{\left(\le...
# 104               $y'=- 4 x \tan{\left(x^{2} \right)}$
# 105             $y'=\frac{2}{\cos{\left(2 x \right)}}$
# 106               $y'=\frac{2}{\sin{\left(x \right)}}$
# 107             $y'=\frac{1}{2 \sin{\left(x \right)}}$
# 108         $y'=\frac{2}{\sin{\left(2 x \right)} - 1}$
# 109  $y'=\frac{a^{2}}{\sqrt{a^{2} - x^{2}}} + \frac...
# 110  $y'=- \frac{1}{\left(\cos{\left(x \right)} + 1...
# 111  $y'=\frac{\left(x^{2} \left(\sin{\left(\log{\l...
#
#                                    texto curso     titulo n_ejercicio  \
# 97   Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 98   Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 99   Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 100  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 101  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 102  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 103  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 104  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 105  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 106  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 107  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 108  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 109  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 110  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 111  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
#
#     dificultad n_columnas puntos  enun_tex  sol_tex
# 97           5          1      1     False    False
# 98           5          1      1     False    False
# 99           5          1      1     False    False
# 100          5          1      1     False    False
# 101          5          1      1     False    False
# 102          5          1      1     False    False
# 103          5          1      1     False    False
# 104          5          1      1     False    False
# 105          5          1      1     False    False
# 106          5          1      1     False    False
# 107          5          1      1     False    False
# 108          5          1      1     False    False
# 109          5          1      1     False    False
# 110          5          1      1     False    False
# 111          5          1      1     False    False
# **Ejercicio: **p27e27
#                                        enunciado_latex  \
# 112                    $y=\frac{x^{2} - 3}{x^{2} + 3}$
# 113  $y=\left(\frac{1 - x}{x + 1}\right)^{\frac{2}{...
# 114                $y=\frac{\log{\left(x \right)}}{x}$
# 115        $y=\frac{e^{x} + e^{- x}}{e^{x} - e^{- x}}$
# 116                $y=\frac{1}{\sin{\left(x \right)}}$
# 117  $y=\operatorname{atan}{\left(\frac{x}{3} \righ...
# 118                      $y=\sin^{2}{\left(x \right)}$
# 119                $y=\left(2 \sqrt{x} - 3\right)^{7}$
# 120                $y=\cos^{5}{\left(7 x^{2} \right)}$
# 121             $y=\sqrt[3]{\left(5 x - 3\right)^{2}}$
# 122               $y=\log{\left(\sqrt{1 - x} \right)}$
# 123  $y=\frac{\log{\left(\sqrt{\tan{\left(x \right)...
# 124            $y=\sqrt[3]{\sin{\left(x^{2} \right)}}$
# 125                            $y=\sqrt{\sqrt{x} + x}$
# 126                          $y=\sqrt{x \sqrt{x + 1}}$
# 127  $y=\log{\left(\left(x \tan{\left(x \right)}\ri...
# 128  $y=\log{\left(\frac{\sqrt[3]{x^{2} - 1}}{x^{2}...
# 129  $y=\log{\left(\sqrt[4]{\frac{1}{\left(x + 1\ri...
# 130                                      $y=x^{x + 1}$
# 131  $y=\left(\frac{\sin{\left(x \right)}}{x}\right...
# 132  $y=e^{2 \operatorname{asin}{\left(x^{2} \right...
#
#                                        enunciado  \
# 112                  diff((x**2 - 3)/(x**2 + 3))
# 113               diff(((1 - x)/(x + 1))**(2/3))
# 114                               diff(log(x)/x)
# 115  diff((exp(x) + exp(-x))/(exp(x) - exp(-x)))
# 116                               diff(1/sin(x))
# 117                              diff(atan(x/3))
# 118                              diff(sin(x)**2)
# 119                     diff((2*sqrt(x) - 3)**7)
# 120                         diff(cos(7*x**2)**5)
# 121                  diff(((5*x - 3)**2)**(1/3))
# 122                       diff(log(sqrt(1 - x)))
# 123               diff(log(sqrt(tan(x)))/log(2))
# 124                       diff(sin(x**2)**(1/3))
# 125                      diff(sqrt(sqrt(x) + x))
# 126                    diff(sqrt(x*sqrt(x + 1)))
# 127                    diff(log(x**2*tan(x)**2))
# 128            diff(log((x**2 - 1)**(1/3)/x**2))
# 129            diff(log(((x + 1)**(-2))**(1/4)))
# 130                             diff(x**(x + 1))
# 131                          diff((sin(x)/x)**x)
# 132                      diff(exp(2*asin(x**2)))
#
#                                               solucion  \
# 112       $y'=\frac{12 x}{\left(x^{2} + 3\right)^{2}}$
# 113  $y'=\frac{4 \left(\frac{1 - x}{x + 1}\right)^{...
# 114       $y'=\frac{1 - \log{\left(x \right)}}{x^{2}}$
# 115   $y'=- \frac{4 e^{2 x}}{e^{4 x} - 2 e^{2 x} + 1}$
# 116  $y'=- \frac{\cos{\left(x \right)}}{\sin^{2}{\l...
# 117                           $y'=\frac{3}{x^{2} + 9}$
# 118                       $y'=\sin{\left(2 x \right)}$
# 119  $y'=\frac{7 \left(2 \sqrt{x} - 3\right)^{6}}{\...
# 120  $y'=- 70 x \sin{\left(7 x^{2} \right)} \cos^{4...
# 121  $y'=\frac{10 \sqrt[3]{\left(5 x - 3\right)^{2}...
# 122                $y'=\frac{1}{2 \left(x - 1\right)}$
# 123  $y'=\frac{1}{\log{\left(2 \right)} \sin{\left(...
# 124  $y'=\frac{2 x \cos{\left(x^{2} \right)}}{3 \si...
# 125  $y'=\frac{2 \sqrt{x} + 1}{4 \sqrt{x} \sqrt{\sq...
# 126  $y'=\frac{\sqrt{x \sqrt{x + 1}} \left(3 x + 2\...
# 127  $y'=\frac{4}{\sin{\left(2 x \right)}} + \frac{...
# 128  $y'=\frac{2 \left(3 - 2 x^{2}\right)}{3 x \lef...
# 129                           $y'=- \frac{1}{2 x + 2}$
# 130  $y'=x^{x} \left(x \log{\left(x \right)} + x + ...
# 131  $y'=\left(\frac{\sin{\left(x \right)}}{x}\righ...
# 132  $y'=\frac{4 x e^{2 \operatorname{asin}{\left(x...
#
#                                    texto curso     titulo n_ejercicio  \
# 112  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 113  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 114  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 115  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 116  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 117  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 118  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 119  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 120  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 121  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 122  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 123  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 124  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 125  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 126  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 127  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 128  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 129  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 130  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 131  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 132  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
#
#     dificultad n_columnas puntos  enun_tex  sol_tex
# 112          5          2      1     False    False
# 113          5          2      1     False    False
# 114          5          2      1     False    False
# 115          5          2      1     False    False
# 116          5          2      1     False    False
# 117          5          2      1     False    False
# 118          5          2      1     False    False
# 119          5          2      1     False    False
# 120          5          2      1     False    False
# 121          5          2      1     False    False
# 122          5          2      1     False    False
# 123          5          2      1     False    False
# 124          5          2      1     False    False
# 125          5          2      1     False    False
# 126          5          2      1     False    False
# 127          5          2      1     False    False
# 128          5          2      1     False    False
# 129          5          2      1     False    False
# 130          5          2      1     False    False
# 131          5          2      1     False    False
# 132          5          2      1     False    False
# **Ejercicio: **p27e27cont
#                                        enunciado_latex  \
# 133            $y=e^{4 x} x^{3} \cos{\left(x \right)}$
# 134  $y=\operatorname{asin}{\left(\frac{2 x - 1}{\s...
# 135  $y=\sin{\left(x^{2} + \cos{\left(x \right)} \r...
# 136      $y=\frac{x \sin{\left(x \right)}}{e^{x} + 1}$
# 137  $y=\operatorname{atan}{\left(\frac{- 4 x^{3} +...
# 138  $y=\log{\left(\frac{\tan{\left(x - 2 \right)} ...
# 139  $y=\sqrt{\log{\left(\tan{\left(x^{2} + 1 \righ...
# 140  $y=\operatorname{asin}{\left(2 x \sqrt{1 - x^{...
# 141  $y=\left(1 - \cos{\left(x \right)}\right) \cot...
# 142  $y=\operatorname{atan}{\left(\frac{\sqrt{x^{2}...
# 143  $y=e^{\log{\left(\sin^{2}{\left(x \right)} \ri...
# 144  $y=- \operatorname{atan}{\left(x \right)} + \o...
# 145  $y=\operatorname{atan}{\left(\frac{x}{\sqrt{1 ...
# 146  $y=\cos^{\log{\left(x^{2} \right)}}{\left(x \r...
# 147  $y=\frac{4 x + 1}{\cos^{2}{\left(2 x^{2} + x +...
# 148    $y=\sin{\left(x \right)} \cos{\left(x \right)}$
# 149  $y=\sqrt[3]{\frac{\sin{\left(3 x \right)}}{1 -...
# 150  $y=\operatorname{asin}{\left(\sqrt{\frac{1 - e...
# 151  $y=\frac{\left(x + 1\right) \operatorname{atan...
# 152  $y=\operatorname{atan}{\left(\sqrt{\frac{1 - \...
# 153  $y=\frac{x \sqrt{1 - x^{2}}}{4} + \left(\frac{...
#
#                                              enunciado  \
# 133                         diff(x**3*exp(4*x)*cos(x))
# 134                    diff(asin(sqrt(5)*(2*x - 1)/5))
# 135                           diff(sin(x**2 + cos(x)))
# 136                        diff(x*sin(x)/(exp(x) + 1))
# 137    diff(atan((-4*x**3 + 4*x)/(x**4 - 6*x**2 + 1)))
# 138     diff(log((tan(x - 2) - 2)/(2*tan(x - 2) - 1)))
# 139                     diff(sqrt(log(tan(x**2 + 1))))
# 140                     diff(asin(2*x*sqrt(1 - x**2)))
# 141                          diff((1 - cos(x))*cot(x))
# 142                 diff(atan((sqrt(x**2 + 1) - 1)/x))
# 143                                    diff(sin(x)**2)
# 144             diff(-atan(x) + atan((x + 1)/(1 - x)))
# 145                       diff(atan(x/sqrt(1 - x**2)))
# 146                            diff(cos(x)**log(x**2))
# 147             diff((4*x + 1)/cos(2*x**2 + x + 1)**2)
# 148                                diff(sin(x)*cos(x))
# 149               diff((sin(3*x)/(1 - sin(x)))**(1/3))
# 150        diff(asin(sqrt((1 - exp(x))/(exp(x) + 1))))
# 151                       diff((x + 1)*atan(x)/log(x))
# 152        diff(atan(sqrt((1 - cos(x))/(cos(x) + 1))))
# 153  diff(x*sqrt(1 - x**2)/4 + (x**3/2 - 1/4)*asin(x))
#
#                                               solucion  \
# 133  $y'=x^{2} \left(- x \sin{\left(x \right)} + 4 ...
# 134              $y'=\frac{1}{\sqrt{- x^{2} + x + 1}}$
# 135  $y'=\left(2 x - \sin{\left(x \right)}\right) \...
# 136  $y'=\frac{- x e^{x} \sin{\left(x \right)} + \l...
# 137                           $y'=\frac{4}{x^{2} + 1}$
# 138  $y'=\frac{3 \left(\tan^{2}{\left(x - 2 \right)...
# 139  $y'=\frac{x \left(\tan^{2}{\left(x^{2} + 1 \ri...
# 140  $y'=\frac{2 \left(1 - 2 x^{2}\right)}{\sqrt{1 ...
# 141  $y'=\frac{\cos{\left(x \right)} - 1}{\sin^{2}{...
# 142            $y'=\frac{1}{2 \left(x^{2} + 1\right)}$
# 143                       $y'=\sin{\left(2 x \right)}$
# 144                                             $y'=0$
# 145                    $y'=\frac{1}{\sqrt{1 - x^{2}}}$
# 146  $y'=\frac{\left(- x \log{\left(x^{2} \right)} ...
# 147  $y'=\frac{2 \left(\left(4 x + 1\right)^{2} \si...
# 148                       $y'=\cos{\left(2 x \right)}$
# 149  $y'=- \frac{\sqrt[3]{- \frac{\sin{\left(3 x \r...
# 150  $y'=\frac{\sqrt{2} \sqrt{- \tanh{\left(\frac{x...
# 151  $y'=\frac{x \left(x + 1\right) \log{\left(x \r...
# 152  $y'=- \frac{\sqrt{- \frac{\cos{\left(x \right)...
# 153  $y'=\frac{x^{2} \left(x + 3 \sqrt{1 - x^{2}} \...
#
#                                    texto curso     titulo n_ejercicio  \
# 133  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 134  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 135  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 136  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 137  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 138  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 139  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 140  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 141  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 142  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 143  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 144  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 145  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 146  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 147  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 148  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 149  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 150  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 151  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 152  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 153  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
#
#     dificultad n_columnas puntos  enun_tex  sol_tex
# 133          5          1      1     False    False
# 134          5          1      1     False    False
# 135          5          1      1     False    False
# 136          5          1      1     False    False
# 137          5          1      1     False    False
# 138          5          1      1     False    False
# 139          5          1      1     False    False
# 140          5          1      1     False    False
# 141          5          1      1     False    False
# 142          5          1      1     False    False
# 143          5          1      1     False    False
# 144          5          1      1     False    False
# 145          5          1      1     False    False
# 146          5          1      1     False    False
# 147          5          1      1     False    False
# 148          5          1      1     False    False
# 149          5          1      1     False    False
# 150          5          1      1     False    False
# 151          5          1      1     False    False
# 152          5          1      1     False    False
# 153          5          1      1     False    False

# %%
escribir_preambulo(fichero, titulo, 'ejercicios')
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **p25e16
#                                       enunciado_latex  \
# 0                                             $y=2 x$
# 1                                         $y=3 x - 5$
# 2                               $y=2 x^{2} - 7 x + 5$
# 3                    $y=7 x^{5} - 3 x^{2} + x + 2345$
# 4                            $y=x \left(x + 2\right)$
# 5           $y=\left(x - 1\right) \left(x + 1\right)$
# 6   $y=\frac{5 x^{4}}{7} - \frac{x^{3}}{55} - \fra...
# 7                          $y=\left(x + 1\right)^{3}$
# 8                  $y=\left(x^{3} + x + 1\right)^{4}$
# 9   $y=- \left(3 x - 1\right)^{2} + \left(3 x + 1\...
# 10                                $y=\frac{1}{x^{2}}$
# 11                                $y=\frac{1}{x + 1}$
# 12                    $y=\frac{x^{2} - 3}{x^{3} + x}$
# 13                                $y=\frac{x + 1}{x}$
# 14   $y=\frac{x \left(x^{2} - 1\right)}{3 x^{2} - 3}$
# 15                                $y=\frac{1}{x^{3}}$
# 16                                $y=x^{\frac{1}{2}}$
# 17                                $y=x^{\frac{2}{3}}$
# 18                               $y=x^{\frac{-2}{3}}$
#
#                                          enunciado  \
# 0                                        diff(2*x)
# 1                                    diff(3*x - 5)
# 2                           diff(2*x**2 - 7*x + 5)
# 3                 diff(7*x**5 - 3*x**2 + x + 2345)
# 4                                  diff(x*(x + 2))
# 5                            diff((x - 1)*(x + 1))
# 6   diff(5*x**4/7 - x**3/55 - 3*x**2/4 + x - 1255)
# 7                                 diff((x + 1)**3)
# 8                          diff((x**3 + x + 1)**4)
# 9               diff(-(3*x - 1)**2 + (3*x + 1)**2)
# 10                                   diff(x**(-2))
# 11                                 diff(1/(x + 1))
# 12                     diff((x**2 - 3)/(x**3 + x))
# 13                                 diff((x + 1)/x)
# 14                 diff(x*(x**2 - 1)/(3*x**2 - 3))
# 15                                   diff(x**(-3))
# 16                                   diff(sqrt(x))
# 17                                  diff(x**(2/3))
# 18                                 diff(x**(-2/3))
#
#                                              solucion  \
# 0                                              $y'=2$
# 1                                              $y'=3$
# 2                                        $y'=4 x - 7$
# 3                             $y'=35 x^{4} - 6 x + 1$
# 4                                        $y'=2 x + 2$
# 5                                            $y'=2 x$
# 6   $y'=\frac{20 x^{3}}{7} - \frac{3 x^{2}}{55} - ...
# 7                       $y'=3 \left(x + 1\right)^{2}$
# 8   $y'=\left(12 x^{2} + 4\right) \left(x^{3} + x ...
# 9                                             $y'=12$
# 10                             $y'=- \frac{2}{x^{3}}$
# 11            $y'=- \frac{1}{\left(x + 1\right)^{2}}$
# 12  $y'=\frac{- x^{4} + 10 x^{2} + 3}{x^{2} \left(...
# 13                             $y'=- \frac{1}{x^{2}}$
# 14                                   $y'=\frac{1}{3}$
# 15                             $y'=- \frac{3}{x^{4}}$
# 16                          $y'=\frac{1}{2 \sqrt{x}}$
# 17                       $y'=\frac{2}{3 \sqrt[3]{x}}$
# 18                 $y'=- \frac{2}{3 x^{\frac{5}{3}}}$
#
#                                   texto curso     titulo n_ejercicio  \
# 0   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 1   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 2   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 3   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 4   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 5   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 6   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 7   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 8   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 9   Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 10  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 11  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 12  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 13  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 14  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 15  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 16  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 17  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
# 18  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e16
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 0           5          2      1     False    False
# 1           5          2      1     False    False
# 2           5          2      1     False    False
# 3           5          2      1     False    False
# 4           5          2      1     False    False
# 5           5          2      1     False    False
# 6           5          2      1     False    False
# 7           5          2      1     False    False
# 8           5          2      1     False    False
# 9           5          2      1     False    False
# 10          5          2      1     False    False
# 11          5          2      1     False    False
# 12          5          2      1     False    False
# 13          5          2      1     False    False
# 14          5          2      1     False    False
# 15          5          2      1     False    False
# 16          5          2      1     False    False
# 17          5          2      1     False    False
# 18          5          2      1     False    False
# **Ejercicio: **p25e16cont
#                                       enunciado_latex  \
# 19  $y=x^{\frac{1}{2}} + x^{\frac{1}{5}} + x^{\fra...
# 20                              $y=\sqrt{3} \sqrt{x}$
# 21                         $y=\frac{x^{3}}{\sqrt{x}}$
# 22                          $y=x^{3} x^{\frac{1}{3}}$
# 23                             $y=\frac{\sqrt{x}}{x}$
# 24                     $y=\left(1 - x^{2}\right)^{3}$
# 25                                 $y=\sqrt{2 x - 4}$
# 26                                   $y=\sqrt{2 - x}$
# 27                    $y=\sqrt[3]{2} \sqrt[3]{x^{2}}$
# 28                             $y=\sqrt{3 x^{2} - 1}$
# 29                       $y=\frac{2 x}{\sqrt{x - 1}}$
# 30                                       $y=\sqrt{1}$
# 31                                        $y=e^{2 x}$
# 32                                        $y=2^{5 x}$
# 33                                $y=8^{3 x^{2} - 1}$
# 34                                    $y=a^{x} x^{a}$
# 35                                   $y=e^{\sqrt{x}}$
# 36  $y=\frac{\log{\left(2 x - 1 \right)}}{\log{\le...
# 37                      $y=\log{\left(x + 3 \right)}$
#
#                               enunciado  \
# 19  diff(x**(1/6) + x**(1/5) + sqrt(x))
# 20                diff(sqrt(3)*sqrt(x))
# 21                       diff(x**(5/2))
# 22                      diff(x**(10/3))
# 23                      diff(1/sqrt(x))
# 24                  diff((1 - x**2)**3)
# 25                  diff(sqrt(2*x - 4))
# 26                    diff(sqrt(2 - x))
# 27         diff(2**(1/3)*(x**2)**(1/3))
# 28               diff(sqrt(3*x**2 - 1))
# 29                diff(2*x/sqrt(x - 1))
# 30                              diff(1)
# 31                       diff(exp(2*x))
# 32                       diff(2**(5*x))
# 33                diff(8**(3*x**2 - 1))
# 34                      diff(a**x*x**a)
# 35                   diff(exp(sqrt(x)))
# 36           diff(log(2*x - 1)/log(10))
# 37                     diff(log(x + 3))
#
#                                              solucion  \
# 19  $y'=\frac{\frac{x^{\frac{49}{30}}}{2} + \frac{...
# 20                   $y'=\frac{\sqrt{3}}{2 \sqrt{x}}$
# 21                   $y'=\frac{5 x^{\frac{3}{2}}}{2}$
# 22                  $y'=\frac{10 x^{\frac{7}{3}}}{3}$
# 23                 $y'=- \frac{1}{2 x^{\frac{3}{2}}}$
# 24              $y'=- 6 x \left(x^{2} - 1\right)^{2}$
# 25               $y'=\frac{\sqrt{2}}{2 \sqrt{x - 2}}$
# 26                    $y'=- \frac{1}{2 \sqrt{2 - x}}$
# 27     $y'=\frac{2 \sqrt[3]{2} \sqrt[3]{x^{2}}}{3 x}$
# 28                $y'=\frac{3 x}{\sqrt{3 x^{2} - 1}}$
# 29  $y'=\frac{x - 2}{\left(x - 1\right)^{\frac{3}{...
# 30                                             $y'=0$
# 31                                     $y'=2 e^{2 x}$
# 32                 $y'=32^{x} \log{\left(32 \right)}$
# 33  $y'=9 \cdot 2^{9 x^{2} - 2} x \log{\left(2 \ri...
# 34  $y'=a^{x} x^{a - 1} \left(a + x \log{\left(a \...
# 35               $y'=\frac{e^{\sqrt{x}}}{2 \sqrt{x}}$
# 36  $y'=\frac{2}{\left(2 x - 1\right) \log{\left(1...
# 37                               $y'=\frac{1}{x + 3}$
#
#                                   texto curso     titulo n_ejercicio  \
# 19  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 20  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 21  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 22  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 23  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 24  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 25  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 26  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 27  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 28  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 29  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 30  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 31  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 32  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 33  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 34  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 35  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 36  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
# 37  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e16cont
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 19          5          2      1     False    False
# 20          5          2      1     False    False
# 21          5          2      1     False    False
# 22          5          2      1     False    False
# 23          5          2      1     False    False
# 24          5          2      1     False    False
# 25          5          2      1     False    False
# 26          5          2      1     False    False
# 27          5          2      1     False    False
# 28          5          2      1     False    False
# 29          5          2      1     False    False
# 30          5          2      1     False    False
# 31          5          2      1     False    False
# 32          5          2      1     False    False
# 33          5          2      1     False    False
# 34          5          2      1     False    False
# 35          5          2      1     False    False
# 36          5          2      1     False    False
# 37          5          2      1     False    False
# **Ejercicio: **p25e17
#                                       enunciado_latex  \
# 38                $y=\log{\left(3 x^{2} - 7 \right)}$
# 39     $y=\log{\left(\left(x - 2\right)^{2} \right)}$
# 40  $y=\frac{\log{\left(x^{2} - 2 x \right)}}{\log...
# 41  $y=\frac{\log{\left(2 x^{3} + 3 x^{2} \right)}...
# 42                   $y=\sqrt{\log{\left(x \right)}}$
# 43                $y=\frac{\log{\left(x \right)}}{x}$
# 44        $y=\log{\left(\frac{1 - x}{x + 1} \right)}$
# 45            $y=\log{\left(\sqrt[4]{x^{3}} \right)}$
# 46  $y=\frac{\log{\left(2 x + 1 \right)}}{\log{\le...
# 47    $y=\log{\left(\frac{e^{x}}{e^{x} - 1} \right)}$
# 48  $y=\frac{1 - \log{\left(x \right)}}{\log{\left...
# 49                            $y=\frac{e^{x}}{x - 1}$
# 50        $y=\frac{e^{x} - e^{- x}}{e^{x} + e^{- x}}$
# 51                           $y=e^{\sqrt{x^{2} + 1}}$
# 52                        $y=\sin{\left(2 x \right)}$
# 53                    $y=\sin{\left(7 x - 3 \right)}$
# 54                        $y=\cos{\left(5 x \right)}$
# 55                      $y=3 \tan{\left(2 x \right)}$
# 56                      $y=\sin^{2}{\left(x \right)}$
# 57                      $y=\sin{\left(x^{2} \right)}$
#
#                                       enunciado  \
# 38                        diff(log(3*x**2 - 7))
# 39                        diff(log((x - 2)**2))
# 40                diff(log(x**2 - 2*x)/log(10))
# 41            diff(log(2*x**3 + 3*x**2)/log(2))
# 42                           diff(sqrt(log(x)))
# 43                               diff(log(x)/x)
# 44                   diff(log((1 - x)/(x + 1)))
# 45                     diff(log((x**3)**(1/4)))
# 46                    diff(log(2*x + 1)/log(4))
# 47               diff(log(exp(x)/(exp(x) - 1)))
# 48              diff((1 - log(x))/(log(x) + 1))
# 49                         diff(exp(x)/(x - 1))
# 50  diff((exp(x) - exp(-x))/(exp(x) + exp(-x)))
# 51                    diff(exp(sqrt(x**2 + 1)))
# 52                               diff(sin(2*x))
# 53                           diff(sin(7*x - 3))
# 54                               diff(cos(5*x))
# 55                             diff(3*tan(2*x))
# 56                              diff(sin(x)**2)
# 57                              diff(sin(x**2))
#
#                                              solucion  \
# 38                       $y'=\frac{6 x}{3 x^{2} - 7}$
# 39                               $y'=\frac{2}{x - 2}$
# 40  $y'=\frac{2 \left(x - 1\right)}{x \left(x - 2\...
# 41  $y'=\frac{6 \left(x + 1\right)}{x \left(2 x + ...
# 42    $y'=\frac{1}{2 x \sqrt{\log{\left(x \right)}}}$
# 43       $y'=\frac{1 - \log{\left(x \right)}}{x^{2}}$
# 44                           $y'=\frac{2}{x^{2} - 1}$
# 45                                 $y'=\frac{3}{4 x}$
# 46  $y'=\frac{1}{\left(2 x + 1\right) \log{\left(2...
# 47                           $y'=\frac{1}{1 - e^{x}}$
# 48  $y'=- \frac{2}{x \left(\log{\left(x \right)} +...
# 49  $y'=\frac{\left(x - 2\right) e^{x}}{x^{2} - 2 ...
# 50     $y'=\frac{4 e^{2 x}}{e^{4 x} + 2 e^{2 x} + 1}$
# 51  $y'=\frac{x e^{\sqrt{x^{2} + 1}}}{\sqrt{x^{2} ...
# 52                     $y'=2 \cos{\left(2 x \right)}$
# 53                 $y'=7 \cos{\left(7 x - 3 \right)}$
# 54                   $y'=- 5 \sin{\left(5 x \right)}$
# 55         $y'=\frac{6}{\cos^{2}{\left(2 x \right)}}$
# 56                       $y'=\sin{\left(2 x \right)}$
# 57                 $y'=2 x \cos{\left(x^{2} \right)}$
#
#                                   texto curso     titulo n_ejercicio  \
# 38  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 39  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 40  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 41  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 42  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 43  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 44  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 45  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 46  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 47  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 48  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 49  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 50  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 51  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 52  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 53  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 54  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 55  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 56  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
# 57  Calcula las siguientes derivadas:\n   2BC  Derivadas      p25e17
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 38          5          2      1     False    False
# 39          5          2      1     False    False
# 40          5          2      1     False    False
# 41          5          2      1     False    False
# 42          5          2      1     False    False
# 43          5          2      1     False    False
# 44          5          2      1     False    False
# 45          5          2      1     False    False
# 46          5          2      1     False    False
# 47          5          2      1     False    False
# 48          5          2      1     False    False
# 49          5          2      1     False    False
# 50          5          2      1     False    False
# 51          5          2      1     False    False
# 52          5          2      1     False    False
# 53          5          2      1     False    False
# 54          5          2      1     False    False
# 55          5          2      1     False    False
# 56          5          2      1     False    False
# 57          5          2      1     False    False
# **Ejercicio: **p25e17cont
#                                       enunciado_latex  \
# 58              $y=\cos^{2}{\left(x^{2} + 1 \right)}$
# 59                    $y=\tan^{3}{\left(5 x \right)}$
# 60                    $y=\sin^{3}{\left(4 x \right)}$
# 61                 $y=\sqrt{\sin{\left(2 x \right)}}$
# 62  $y=\log{\left(- \tan{\left(x - 1 \right)} \rig...
# 63                $y=\sqrt[3]{\sin{\left(x \right)}}$
# 64  $y=\sin^{3}{\left(x \right)} \cos{\left(x \rig...
# 65                    $y=\sec{\left(5 x + 2 \right)}$
# 66         $y=\operatorname{asin}{\left(2 x \right)}$
# 67       $y=\operatorname{acos}{\left(x^{2} \right)}$
# 68  $y=\operatorname{atan}{\left(\frac{x - 1}{1 - ...
# 69  $y=\operatorname{asin}{\left(\frac{x + 1}{x - ...
# 70  $y=\tan^{2}{\left(\sin{\left(x \right)} \right)}$
# 71            $y=\sin^{\frac{1}{x}}{\left(x \right)}$
# 72                      $y=x^{\tan{\left(x \right)}}$
# 73  $y=2^{\log{\left(\cos{\left(x \right)} \right)}}$
# 74  $y=\sin^{\operatorname{atan}{\left(x \right)}}...
# 75       $y=\operatorname{atan}^{x}{\left(x \right)}$
# 76                      $y=x^{\sec{\left(x \right)}}$
#
#                       enunciado  \
# 58       diff(cos(x**2 + 1)**2)
# 59            diff(tan(5*x)**3)
# 60            diff(sin(4*x)**3)
# 61         diff(sqrt(sin(2*x)))
# 62       diff(log(-tan(x - 1)))
# 63          diff(sin(x)**(1/3))
# 64       diff(sin(x)**3*cos(x))
# 65           diff(sec(5*x + 2))
# 66              diff(asin(2*x))
# 67             diff(acos(x**2))
# 68  diff(atan((x - 1)/(1 - x)))
# 69  diff(asin((x + 1)/(x - 1)))
# 70         diff(tan(sin(x))**2)
# 71          diff(sin(x)**(1/x))
# 72              diff(x**tan(x))
# 73         diff(2**log(cos(x)))
# 74        diff(sin(x)**atan(x))
# 75             diff(atan(x)**x)
# 76              diff(x**sec(x))
#
#                                              solucion  \
# 58         $y'=- 2 x \sin{\left(2 x^{2} + 2 \right)}$
# 59  $y'=\frac{15 \tan^{2}{\left(5 x \right)}}{\cos...
# 60  $y'=12 \sin^{2}{\left(4 x \right)} \cos{\left(...
# 61  $y'=\frac{\cos{\left(2 x \right)}}{\sqrt{\sin{...
# 62  $y'=\tan{\left(x - 1 \right)} + \frac{1}{\tan{...
# 63  $y'=\frac{\cos{\left(x \right)}}{3 \sin^{\frac...
# 64  $y'=\left(3 - 4 \sin^{2}{\left(x \right)}\righ...
# 65  $y'=5 \tan{\left(5 x + 2 \right)} \sec{\left(5...
# 66                  $y'=\frac{2}{\sqrt{1 - 4 x^{2}}}$
# 67                $y'=- \frac{2 x}{\sqrt{1 - x^{4}}}$
# 68                                             $y'=0$
# 69  $y'=- \frac{1}{\sqrt{- \frac{x}{x^{2} - 2 x + ...
# 70  $y'=\frac{2 \cos{\left(x \right)} \tan{\left(\...
# 71  $y'=\frac{\left(x \cos{\left(x \right)} - \log...
# 72  $y'=x^{\tan{\left(x \right)} - 1} \left(\frac{...
# 73  $y'=- 2^{\log{\left(\cos{\left(x \right)} \rig...
# 74  $y'=\frac{\left(\left(x^{2} + 1\right) \cos{\l...
# 75  $y'=\frac{\left(x + \left(x^{2} + 1\right) \lo...
# 76  $y'=x^{\sec{\left(x \right)} - 1} \left(x \log...
#
#                                   texto curso     titulo n_ejercicio  \
# 58  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 59  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 60  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 61  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 62  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 63  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 64  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 65  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 66  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 67  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 68  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 69  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 70  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 71  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 72  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 73  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 74  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 75  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
# 76  Calcula las siguientes derivadas:\n   2BC  Derivadas  p25e17cont
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 58          5          1      1     False    False
# 59          5          1      1     False    False
# 60          5          1      1     False    False
# 61          5          1      1     False    False
# 62          5          1      1     False    False
# 63          5          1      1     False    False
# 64          5          1      1     False    False
# 65          5          1      1     False    False
# 66          5          1      1     False    False
# 67          5          1      1     False    False
# 68          5          1      1     False    False
# 69          5          1      1     False    False
# 70          5          1      1     False    False
# 71          5          1      1     False    False
# 72          5          1      1     False    False
# 73          5          1      1     False    False
# 74          5          1      1     False    False
# 75          5          1      1     False    False
# 76          5          1      1     False    False
# **Ejercicio: **p26e18
#                                       enunciado_latex  \
# 77                     $y=\left(x^{2} - 3\right)^{4}$
# 78                       $y=\left(1 - 5 x\right)^{6}$
# 79                    $y=\sqrt[3]{3} \sqrt[3]{x^{2}}$
# 80  $y=\left(x^{2} + 4\right) \left(3 x^{3} + 1\ri...
# 81                 $y=\sqrt{2} \sqrt{x} + 2 \sqrt{x}$
# 82  $y=\log{\left(\frac{x^{4}}{\left(3 x + 4\right...
# 83  $y=\log{\left(\sqrt{\frac{x - 1}{x + 1}} \righ...
# 84     $y=\log{\left(\left(x + 3\right)^{2} \right)}$
# 85                $y=x^{2} \log{\left(x \right)} - x$
# 86  $y=\log{\left(\left(x^{2} + 1\right) \left(2 x...
# 87       $y=\log{\left(x + \sqrt{x^{2} + 1} \right)}$
# 88                    $y=x^{2} \sin{\left(x \right)}$
# 89   $y=\operatorname{asin}{\left(x^{2} + x \right)}$
# 90  $y=x^{2} \operatorname{acos}{\left(\frac{2}{x}...
# 91  $y=\log{\left(\frac{e^{x} - 1}{2 e^{x}} \right)}$
# 92            $y=\frac{\log{\left(x^{2} \right)}}{x}$
# 93                            $y=2^{x^{2} + 3 x + 1}$
# 94                                    $y=2^{x^{2}} x$
# 95                      $y=2^{\sin{\left(x \right)}}$
# 96                      $y=e^{\tan{\left(x \right)}}$
#
#                                    enunciado  \
# 77                       diff((x**2 - 3)**4)
# 78                        diff((1 - 5*x)**6)
# 79              diff(3**(1/3)*(x**2)**(1/3))
# 80             diff((x**2 + 4)*(3*x**3 + 1))
# 81         diff(sqrt(2)*sqrt(x) + 2*sqrt(x))
# 82              diff(log(x**4/(3*x + 4)**3))
# 83          diff(log(sqrt((x - 1)/(x + 1))))
# 84                     diff(log((x + 3)**2))
# 85                     diff(x**2*log(x) - x)
# 86  diff(log((x**2 + 1)*(2*x**2 + 3*x + 1)))
# 87             diff(log(x + sqrt(x**2 + 1)))
# 88                         diff(x**2*sin(x))
# 89                      diff(asin(x**2 + x))
# 90                      diff(x**2*acos(2/x))
# 91         diff(log((exp(x) - 1)*exp(-x)/2))
# 92                         diff(log(x**2)/x)
# 93                 diff(2**(x**2 + 3*x + 1))
# 94                         diff(2**(x**2)*x)
# 95                           diff(2**sin(x))
# 96                         diff(exp(tan(x)))
#
#                                              solucion  \
# 77                $y'=8 x \left(x^{2} - 3\right)^{3}$
# 78                   $y'=30 \left(5 x - 1\right)^{5}$
# 79     $y'=\frac{2 \sqrt[3]{3} \sqrt[3]{x^{2}}}{3 x}$
# 80            $y'=x \left(15 x^{3} + 36 x + 2\right)$
# 81               $y'=\frac{\sqrt{2} + 2}{2 \sqrt{x}}$
# 82       $y'=\frac{3 x + 16}{x \left(3 x + 4\right)}$
# 83                           $y'=\frac{1}{x^{2} - 1}$
# 84                               $y'=\frac{2}{x + 3}$
# 85             $y'=2 x \log{\left(x \right)} + x - 1$
# 86  $y'=\frac{8 x^{3} + 9 x^{2} + 6 x + 3}{2 x^{4}...
# 87                    $y'=\frac{1}{\sqrt{x^{2} + 1}}$
# 88  $y'=x \left(x \cos{\left(x \right)} + 2 \sin{\...
# 89  $y'=\frac{2 x + 1}{\sqrt{- x^{2} \left(x + 1\r...
# 90  $y'=2 x \operatorname{acos}{\left(\frac{2}{x} ...
# 91                           $y'=\frac{1}{e^{x} - 1}$
# 92   $y'=\frac{2 - \log{\left(x^{2} \right)}}{x^{2}}$
# 93  $y'=2^{x \left(x + 3\right)} \left(2 x + 3\rig...
# 94  $y'=2^{x^{2}} \left(x^{2} \log{\left(4 \right)...
# 95  $y'=2^{\sin{\left(x \right)}} \log{\left(2 \ri...
# 96  $y'=\frac{e^{\tan{\left(x \right)}}}{\cos^{2}{...
#
#                                   texto curso     titulo n_ejercicio  \
# 77  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 78  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 79  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 80  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 81  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 82  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 83  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 84  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 85  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 86  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 87  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 88  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 89  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 90  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 91  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 92  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 93  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 94  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 95  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
# 96  Calcula las siguientes derivadas:\n   2BC  Derivadas      p26e18
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 77          5          2      1     False    False
# 78          5          2      1     False    False
# 79          5          2      1     False    False
# 80          5          2      1     False    False
# 81          5          2      1     False    False
# 82          5          2      1     False    False
# 83          5          2      1     False    False
# 84          5          2      1     False    False
# 85          5          2      1     False    False
# 86          5          2      1     False    False
# 87          5          2      1     False    False
# 88          5          2      1     False    False
# 89          5          2      1     False    False
# 90          5          2      1     False    False
# 91          5          2      1     False    False
# 92          5          2      1     False    False
# 93          5          2      1     False    False
# 94          5          2      1     False    False
# 95          5          2      1     False    False
# 96          5          2      1     False    False
# **Ejercicio: **p26e18cont
#                                        enunciado_latex  \
# 97                       $y=x^{\log{\left(x \right)}}$
# 98                                 $y=x^{\frac{1}{x}}$
# 99   $y=\cos^{\sin{\left(x \right)}}{\left(x \right)}$
# 100                  $y=\sin^{3}{\left(x^{3} \right)}$
# 101  $y=\operatorname{asin}{\left(\cos{\left(x \rig...
# 102  $y=\operatorname{asin}{\left(\log{\left(x \rig...
# 103  $y=3 \sin^{2}{\left(\left(2 x + 1\right)^{3} \...
# 104  $y=\log{\left(\cos^{2}{\left(x^{2} \right)} \r...
# 105  $y=\log{\left(\sqrt{\frac{\sin{\left(2 x \righ...
# 106  $y=\log{\left(\frac{1 - \cos{\left(x \right)}}...
# 107  $y=\frac{\log{\left(\tan{\left(\frac{x}{2} \ri...
# 108  $y=\frac{\sin{\left(x \right)} + \cos{\left(x ...
# 109  $y=a^{2} \operatorname{asin}{\left(\frac{x}{a}...
# 110  $y=- \frac{\log{\left(\tan{\left(\frac{x}{2} \...
# 111  $y=e^{x} \left(x - 1\right) \left(\frac{\sin{\...
#
#                                              enunciado  \
# 97                                     diff(x**log(x))
# 98                                      diff(x**(1/x))
# 99                                diff(cos(x)**sin(x))
# 100                                 diff(sin(x**3)**3)
# 101                                 diff(asin(cos(x)))
# 102                                 diff(asin(log(x)))
# 103                       diff(3*sin((2*x + 1)**3)**2)
# 104                            diff(log(cos(x**2)**2))
# 105     diff(log(sqrt((sin(2*x) + 1)/(1 - sin(2*x)))))
# 106               diff(log((1 - cos(x))/(cos(x) + 1)))
# 107                              diff(log(tan(x/2))/2)
# 108          diff((sin(x) + cos(x))/(sin(x) - cos(x)))
# 109         diff(a**2*asin(x/a) + x*sqrt(a**2 - x**2))
# 110      diff(-log(tan(x/2))/2 + cos(x)/(2*sin(x)**2))
# 111  diff((x - 1)*(sin(log(x))/2 + cos(log(x)))*exp...
#
#                                               solucion  \
# 97   $y'=2 x^{\log{\left(x \right)} - 1} \log{\left...
# 98   $y'=x^{-2 + \frac{1}{x}} \left(1 - \log{\left(...
# 99   $y'=\left(\log{\left(\cos{\left(x \right)} \ri...
# 100  $y'=9 x^{2} \sin^{2}{\left(x^{3} \right)} \cos...
# 101  $y'=- \frac{\sin{\left(x \right)}}{\sqrt{\sin^...
# 102  $y'=\frac{1}{x \sqrt{1 - \log{\left(x \right)}...
# 103  $y'=36 \left(2 x + 1\right)^{2} \sin{\left(\le...
# 104               $y'=- 4 x \tan{\left(x^{2} \right)}$
# 105             $y'=\frac{2}{\cos{\left(2 x \right)}}$
# 106               $y'=\frac{2}{\sin{\left(x \right)}}$
# 107             $y'=\frac{1}{2 \sin{\left(x \right)}}$
# 108         $y'=\frac{2}{\sin{\left(2 x \right)} - 1}$
# 109  $y'=\frac{a^{2}}{\sqrt{a^{2} - x^{2}}} + \frac...
# 110  $y'=- \frac{1}{\left(\cos{\left(x \right)} + 1...
# 111  $y'=\frac{\left(x^{2} \left(\sin{\left(\log{\l...
#
#                                    texto curso     titulo n_ejercicio  \
# 97   Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 98   Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 99   Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 100  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 101  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 102  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 103  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 104  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 105  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 106  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 107  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 108  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 109  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 110  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
# 111  Calcula las siguientes derivadas:\n   2BC  Derivadas  p26e18cont
#
#     dificultad n_columnas puntos  enun_tex  sol_tex
# 97           5          1      1     False    False
# 98           5          1      1     False    False
# 99           5          1      1     False    False
# 100          5          1      1     False    False
# 101          5          1      1     False    False
# 102          5          1      1     False    False
# 103          5          1      1     False    False
# 104          5          1      1     False    False
# 105          5          1      1     False    False
# 106          5          1      1     False    False
# 107          5          1      1     False    False
# 108          5          1      1     False    False
# 109          5          1      1     False    False
# 110          5          1      1     False    False
# 111          5          1      1     False    False
# **Ejercicio: **p27e27
#                                        enunciado_latex  \
# 112                    $y=\frac{x^{2} - 3}{x^{2} + 3}$
# 113  $y=\left(\frac{1 - x}{x + 1}\right)^{\frac{2}{...
# 114                $y=\frac{\log{\left(x \right)}}{x}$
# 115        $y=\frac{e^{x} + e^{- x}}{e^{x} - e^{- x}}$
# 116                $y=\frac{1}{\sin{\left(x \right)}}$
# 117  $y=\operatorname{atan}{\left(\frac{x}{3} \righ...
# 118                      $y=\sin^{2}{\left(x \right)}$
# 119                $y=\left(2 \sqrt{x} - 3\right)^{7}$
# 120                $y=\cos^{5}{\left(7 x^{2} \right)}$
# 121             $y=\sqrt[3]{\left(5 x - 3\right)^{2}}$
# 122               $y=\log{\left(\sqrt{1 - x} \right)}$
# 123  $y=\frac{\log{\left(\sqrt{\tan{\left(x \right)...
# 124            $y=\sqrt[3]{\sin{\left(x^{2} \right)}}$
# 125                            $y=\sqrt{\sqrt{x} + x}$
# 126                          $y=\sqrt{x \sqrt{x + 1}}$
# 127  $y=\log{\left(\left(x \tan{\left(x \right)}\ri...
# 128  $y=\log{\left(\frac{\sqrt[3]{x^{2} - 1}}{x^{2}...
# 129  $y=\log{\left(\sqrt[4]{\frac{1}{\left(x + 1\ri...
# 130                                      $y=x^{x + 1}$
# 131  $y=\left(\frac{\sin{\left(x \right)}}{x}\right...
# 132  $y=e^{2 \operatorname{asin}{\left(x^{2} \right...
#
#                                        enunciado  \
# 112                  diff((x**2 - 3)/(x**2 + 3))
# 113               diff(((1 - x)/(x + 1))**(2/3))
# 114                               diff(log(x)/x)
# 115  diff((exp(x) + exp(-x))/(exp(x) - exp(-x)))
# 116                               diff(1/sin(x))
# 117                              diff(atan(x/3))
# 118                              diff(sin(x)**2)
# 119                     diff((2*sqrt(x) - 3)**7)
# 120                         diff(cos(7*x**2)**5)
# 121                  diff(((5*x - 3)**2)**(1/3))
# 122                       diff(log(sqrt(1 - x)))
# 123               diff(log(sqrt(tan(x)))/log(2))
# 124                       diff(sin(x**2)**(1/3))
# 125                      diff(sqrt(sqrt(x) + x))
# 126                    diff(sqrt(x*sqrt(x + 1)))
# 127                    diff(log(x**2*tan(x)**2))
# 128            diff(log((x**2 - 1)**(1/3)/x**2))
# 129            diff(log(((x + 1)**(-2))**(1/4)))
# 130                             diff(x**(x + 1))
# 131                          diff((sin(x)/x)**x)
# 132                      diff(exp(2*asin(x**2)))
#
#                                               solucion  \
# 112       $y'=\frac{12 x}{\left(x^{2} + 3\right)^{2}}$
# 113  $y'=\frac{4 \left(\frac{1 - x}{x + 1}\right)^{...
# 114       $y'=\frac{1 - \log{\left(x \right)}}{x^{2}}$
# 115   $y'=- \frac{4 e^{2 x}}{e^{4 x} - 2 e^{2 x} + 1}$
# 116  $y'=- \frac{\cos{\left(x \right)}}{\sin^{2}{\l...
# 117                           $y'=\frac{3}{x^{2} + 9}$
# 118                       $y'=\sin{\left(2 x \right)}$
# 119  $y'=\frac{7 \left(2 \sqrt{x} - 3\right)^{6}}{\...
# 120  $y'=- 70 x \sin{\left(7 x^{2} \right)} \cos^{4...
# 121  $y'=\frac{10 \sqrt[3]{\left(5 x - 3\right)^{2}...
# 122                $y'=\frac{1}{2 \left(x - 1\right)}$
# 123  $y'=\frac{1}{\log{\left(2 \right)} \sin{\left(...
# 124  $y'=\frac{2 x \cos{\left(x^{2} \right)}}{3 \si...
# 125  $y'=\frac{2 \sqrt{x} + 1}{4 \sqrt{x} \sqrt{\sq...
# 126  $y'=\frac{\sqrt{x \sqrt{x + 1}} \left(3 x + 2\...
# 127  $y'=\frac{4}{\sin{\left(2 x \right)}} + \frac{...
# 128  $y'=\frac{2 \left(3 - 2 x^{2}\right)}{3 x \lef...
# 129                           $y'=- \frac{1}{2 x + 2}$
# 130  $y'=x^{x} \left(x \log{\left(x \right)} + x + ...
# 131  $y'=\left(\frac{\sin{\left(x \right)}}{x}\righ...
# 132  $y'=\frac{4 x e^{2 \operatorname{asin}{\left(x...
#
#                                    texto curso     titulo n_ejercicio  \
# 112  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 113  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 114  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 115  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 116  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 117  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 118  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 119  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 120  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 121  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 122  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 123  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 124  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 125  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 126  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 127  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 128  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 129  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 130  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 131  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
# 132  Calcula las siguientes derivadas:\n   2BC  Derivadas      p27e27
#
#     dificultad n_columnas puntos  enun_tex  sol_tex
# 112          5          2      1     False    False
# 113          5          2      1     False    False
# 114          5          2      1     False    False
# 115          5          2      1     False    False
# 116          5          2      1     False    False
# 117          5          2      1     False    False
# 118          5          2      1     False    False
# 119          5          2      1     False    False
# 120          5          2      1     False    False
# 121          5          2      1     False    False
# 122          5          2      1     False    False
# 123          5          2      1     False    False
# 124          5          2      1     False    False
# 125          5          2      1     False    False
# 126          5          2      1     False    False
# 127          5          2      1     False    False
# 128          5          2      1     False    False
# 129          5          2      1     False    False
# 130          5          2      1     False    False
# 131          5          2      1     False    False
# 132          5          2      1     False    False
# **Ejercicio: **p27e27cont
#                                        enunciado_latex  \
# 133            $y=e^{4 x} x^{3} \cos{\left(x \right)}$
# 134  $y=\operatorname{asin}{\left(\frac{2 x - 1}{\s...
# 135  $y=\sin{\left(x^{2} + \cos{\left(x \right)} \r...
# 136      $y=\frac{x \sin{\left(x \right)}}{e^{x} + 1}$
# 137  $y=\operatorname{atan}{\left(\frac{- 4 x^{3} +...
# 138  $y=\log{\left(\frac{\tan{\left(x - 2 \right)} ...
# 139  $y=\sqrt{\log{\left(\tan{\left(x^{2} + 1 \righ...
# 140  $y=\operatorname{asin}{\left(2 x \sqrt{1 - x^{...
# 141  $y=\left(1 - \cos{\left(x \right)}\right) \cot...
# 142  $y=\operatorname{atan}{\left(\frac{\sqrt{x^{2}...
# 143  $y=e^{\log{\left(\sin^{2}{\left(x \right)} \ri...
# 144  $y=- \operatorname{atan}{\left(x \right)} + \o...
# 145  $y=\operatorname{atan}{\left(\frac{x}{\sqrt{1 ...
# 146  $y=\cos^{\log{\left(x^{2} \right)}}{\left(x \r...
# 147  $y=\frac{4 x + 1}{\cos^{2}{\left(2 x^{2} + x +...
# 148    $y=\sin{\left(x \right)} \cos{\left(x \right)}$
# 149  $y=\sqrt[3]{\frac{\sin{\left(3 x \right)}}{1 -...
# 150  $y=\operatorname{asin}{\left(\sqrt{\frac{1 - e...
# 151  $y=\frac{\left(x + 1\right) \operatorname{atan...
# 152  $y=\operatorname{atan}{\left(\sqrt{\frac{1 - \...
# 153  $y=\frac{x \sqrt{1 - x^{2}}}{4} + \left(\frac{...
#
#                                              enunciado  \
# 133                         diff(x**3*exp(4*x)*cos(x))
# 134                    diff(asin(sqrt(5)*(2*x - 1)/5))
# 135                           diff(sin(x**2 + cos(x)))
# 136                        diff(x*sin(x)/(exp(x) + 1))
# 137    diff(atan((-4*x**3 + 4*x)/(x**4 - 6*x**2 + 1)))
# 138     diff(log((tan(x - 2) - 2)/(2*tan(x - 2) - 1)))
# 139                     diff(sqrt(log(tan(x**2 + 1))))
# 140                     diff(asin(2*x*sqrt(1 - x**2)))
# 141                          diff((1 - cos(x))*cot(x))
# 142                 diff(atan((sqrt(x**2 + 1) - 1)/x))
# 143                                    diff(sin(x)**2)
# 144             diff(-atan(x) + atan((x + 1)/(1 - x)))
# 145                       diff(atan(x/sqrt(1 - x**2)))
# 146                            diff(cos(x)**log(x**2))
# 147             diff((4*x + 1)/cos(2*x**2 + x + 1)**2)
# 148                                diff(sin(x)*cos(x))
# 149               diff((sin(3*x)/(1 - sin(x)))**(1/3))
# 150        diff(asin(sqrt((1 - exp(x))/(exp(x) + 1))))
# 151                       diff((x + 1)*atan(x)/log(x))
# 152        diff(atan(sqrt((1 - cos(x))/(cos(x) + 1))))
# 153  diff(x*sqrt(1 - x**2)/4 + (x**3/2 - 1/4)*asin(x))
#
#                                               solucion  \
# 133  $y'=x^{2} \left(- x \sin{\left(x \right)} + 4 ...
# 134              $y'=\frac{1}{\sqrt{- x^{2} + x + 1}}$
# 135  $y'=\left(2 x - \sin{\left(x \right)}\right) \...
# 136  $y'=\frac{- x e^{x} \sin{\left(x \right)} + \l...
# 137                           $y'=\frac{4}{x^{2} + 1}$
# 138  $y'=\frac{3 \left(\tan^{2}{\left(x - 2 \right)...
# 139  $y'=\frac{x \left(\tan^{2}{\left(x^{2} + 1 \ri...
# 140  $y'=\frac{2 \left(1 - 2 x^{2}\right)}{\sqrt{1 ...
# 141  $y'=\frac{\cos{\left(x \right)} - 1}{\sin^{2}{...
# 142            $y'=\frac{1}{2 \left(x^{2} + 1\right)}$
# 143                       $y'=\sin{\left(2 x \right)}$
# 144                                             $y'=0$
# 145                    $y'=\frac{1}{\sqrt{1 - x^{2}}}$
# 146  $y'=\frac{\left(- x \log{\left(x^{2} \right)} ...
# 147  $y'=\frac{2 \left(\left(4 x + 1\right)^{2} \si...
# 148                       $y'=\cos{\left(2 x \right)}$
# 149  $y'=- \frac{\sqrt[3]{- \frac{\sin{\left(3 x \r...
# 150  $y'=\frac{\sqrt{2} \sqrt{- \tanh{\left(\frac{x...
# 151  $y'=\frac{x \left(x + 1\right) \log{\left(x \r...
# 152  $y'=- \frac{\sqrt{- \frac{\cos{\left(x \right)...
# 153  $y'=\frac{x^{2} \left(x + 3 \sqrt{1 - x^{2}} \...
#
#                                    texto curso     titulo n_ejercicio  \
# 133  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 134  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 135  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 136  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 137  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 138  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 139  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 140  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 141  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 142  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 143  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 144  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 145  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 146  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 147  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 148  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 149  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 150  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 151  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 152  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
# 153  Calcula las siguientes derivadas:\n   2BC  Derivadas  p27e27cont
#
#     dificultad n_columnas puntos  enun_tex  sol_tex
# 133          5          1      1     False    False
# 134          5          1      1     False    False
# 135          5          1      1     False    False
# 136          5          1      1     False    False
# 137          5          1      1     False    False
# 138          5          1      1     False    False
# 139          5          1      1     False    False
# 140          5          1      1     False    False
# 141          5          1      1     False    False
# 142          5          1      1     False    False
# 143          5          1      1     False    False
# 144          5          1      1     False    False
# 145          5          1      1     False    False
# 146          5          1      1     False    False
# 147          5          1      1     False    False
# 148          5          1      1     False    False
# 149          5          1      1     False    False
# 150          5          1      1     False    False
# 151          5          1      1     False    False
# 152          5          1      1     False    False
# 153          5          1      1     False    False
